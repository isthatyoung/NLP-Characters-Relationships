# %%
import gensim
import numpy as np
import nltk
import re
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd
from nltk.tokenize import sent_tokenize
import multiprocessing
import os
from pathlib import Path
import io
from gensim.models import Phrases

# %%
dir = '../final_data/'
files = os.listdir(dir)
potter_corpus = u''
for i in range(7):
    with io.open(dir + 'book{}.txt'.format(i+1), 'r', encoding='utf-8') as file:
        potter_corpus += file.read()
    potter_corpus += ' '
print(potter_corpus[:1000])
# Out:
# the boy who lived mr. and mrs. dursley of number four privet drive were proud to say that they were perfectly normal thank you very much. they were the last people you’d expect to be involved in anything strange or mysterious because they just didn’t hold with such nonsense. mr. dursley was the director of a firm called grunnings which made drills. he was a big beefy man with hardly any neck although he did have a very large mustache. mrs. dursley was thin and blonde and had nearly twice the usual amount of neck which came in very useful as she spent so much of her time craning over garden fences spying on the neighbors. the dursley s had a small son called dudley and in their opinion there was no finer boy anywhere. the dursleys had everything they wanted but they also had a secret and their greatest fear was that somebody would discover it. they didn’t think they could bear it if anyone found out about the potters. mrs. potter was mrs. dursley’s sister but they hadn’t met for several

# %%
sentences  = sent_tokenize(potter_corpus)

# %%
split_sentences = []
for sentence in sentences:
    processed = re.sub("[^a-zA-Z]"," ", sentence)
    words = processed.split()
    split_sentences.append(words)
# Out:
# ['they',
#  'were',
#  'the',
#  'last',
#  'people',
#  'you',
#  'd',
#  'expect',
#  'to',
#  'be',
#  'involved',
#  'in',
#  'anything',
#  'strange',
#  'or',
#  'mysterious',
#  'because',
#  'they',
#  'just',
#  'didn',
#  't',
#  'hold',
#  'with',
#  'such',
#  'nonsense']

# %%
skip_gram = 1
workers = multiprocessing.cpu_count()
bigram_transformer = Phrases(split_sentences)

# %%
model = gensim.models.word2vec.Word2Vec(bigram_transformer[split_sentences], workers=workers, sg=skip_gram, min_count=5)
# Out:
# (8184636, 11228960)

# %%
model.train(split_sentences, total_examples=sum([len(sentence) for sentence in sentences]), epochs=20)
# Out:
# (16364995, 22457920)

# %%
model.wv.vocab
# Out:
# {'the': <gensim.models.keyedvectors.Vocab at 0x126b6ac18>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x129adbbe0>,
#  'who_lived': <gensim.models.keyedvectors.Vocab at 0x129ac52b0>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x129ac5e48>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x129ac5550>,
#  'mrs_dursley': <gensim.models.keyedvectors.Vocab at 0x129ac5cf8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x129ac5668>,
#  'number_four': <gensim.models.keyedvectors.Vocab at 0x129ac5898>,
#  'privet_drive': <gensim.models.keyedvectors.Vocab at 0x129ac5860>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x129ac59e8>,
#  'proud': <gensim.models.keyedvectors.Vocab at 0x129ac5160>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x129ac5dd8>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x129ac5828>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x129ac54a8>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x129ac5be0>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x129ac5b38>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x129ac5358>,
#  'thank_you': <gensim.models.keyedvectors.Vocab at 0x129ac52e8>,
#  'very_much': <gensim.models.keyedvectors.Vocab at 0x129ac5240>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x129aca898>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x129acae48>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x129aca470>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x11f735668>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x11f735860>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x11f73b710>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x11f73b7f0>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x11f73bd68>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x11f73b588>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x11f73bfd0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x11f73b5f8>,
#  'mysterious': <gensim.models.keyedvectors.Vocab at 0x11f73b128>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x11f73b978>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x11f73be80>,
#  'didn_t': <gensim.models.keyedvectors.Vocab at 0x11f73b6d8>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x11f73b160>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x11f73be48>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x11f73bac8>,
#  'nonsense': <gensim.models.keyedvectors.Vocab at 0x11f73b550>,
#  'mr_dursley': <gensim.models.keyedvectors.Vocab at 0x11f73b2b0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x11f73bf60>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x11f73b4e0>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x11f73b5c0>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x11f73b080>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x11f73b860>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x11f73b7b8>,
#  'drills': <gensim.models.keyedvectors.Vocab at 0x11f73ba58>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x11f73ba20>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x11f73bc50>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x11f73bb38>,
#  'hardly_any': <gensim.models.keyedvectors.Vocab at 0x11f73b390>,
#  'neck': <gensim.models.keyedvectors.Vocab at 0x11f73bda0>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x11f73ba90>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x11f73bef0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x11f73b0b8>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x11f73b048>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x11f73fcf8>,
#  'mustache': <gensim.models.keyedvectors.Vocab at 0x11f73f128>,
#  'thin': <gensim.models.keyedvectors.Vocab at 0x11f73fa90>,
#  'blonde': <gensim.models.keyedvectors.Vocab at 0x11f73f080>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x11f73fe10>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x11f73f9e8>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x11f73f588>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x11f73f7f0>,
#  'amount_of': <gensim.models.keyedvectors.Vocab at 0x11f73f208>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x11f73fdd8>,
#  'useful': <gensim.models.keyedvectors.Vocab at 0x129ae1eb8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x129ac9d30>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x129ac9b70>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x129ac9be0>,
#  'so_much': <gensim.models.keyedvectors.Vocab at 0x129ac96d8>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x129ac9048>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x129ac90b8>,
#  'craning': <gensim.models.keyedvectors.Vocab at 0x129ac93c8>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x129ae95c0>,
#  'garden': <gensim.models.keyedvectors.Vocab at 0x129ae9908>,
#  'spying': <gensim.models.keyedvectors.Vocab at 0x129ae9b00>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x129ae99b0>,
#  'neighbors': <gensim.models.keyedvectors.Vocab at 0x129ae9a90>,
#  'dursley': <gensim.models.keyedvectors.Vocab at 0x129ae9630>,
#  's': <gensim.models.keyedvectors.Vocab at 0x129ae9eb8>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x129ae9860>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x129ae9b38>,
#  'dudley': <gensim.models.keyedvectors.Vocab at 0x129ae9cf8>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x129ae9ba8>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x129ae9e48>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x129ae9d68>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x129ae9710>,
#  'finer': <gensim.models.keyedvectors.Vocab at 0x129ae9588>,
#  'anywhere': <gensim.models.keyedvectors.Vocab at 0x129ae9ac8>,
#  'dursleys': <gensim.models.keyedvectors.Vocab at 0x129ae9e10>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x129ae90f0>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x129ae9748>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x129ae9a58>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x129ae96d8>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x11ff00780>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x11ff009e8>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x11ff00940>,
#  'somebody': <gensim.models.keyedvectors.Vocab at 0x11ff00b70>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x11ff00be0>,
#  'discover': <gensim.models.keyedvectors.Vocab at 0x11ff004a8>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x11ff00518>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x11ff00240>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x11ff00908>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x11ff00748>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x11ff00208>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x11ff00c50>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x11ff006d8>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x11ff00198>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x11ff00860>,
#  'potters': <gensim.models.keyedvectors.Vocab at 0x11ff00128>,
#  'mrs': <gensim.models.keyedvectors.Vocab at 0x11ff00b00>,
#  'potter': <gensim.models.keyedvectors.Vocab at 0x129ad0a90>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x129ad0a58>,
#  'hadn_t': <gensim.models.keyedvectors.Vocab at 0x129ad09e8>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x129ad02b0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x129ad00b8>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x129ad0a20>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x129ad0518>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x129ad0cf8>,
#  'pretended': <gensim.models.keyedvectors.Vocab at 0x129ad00f0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x129ad0128>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x129ad0ba8>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x129ad0d30>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x129ad04e0>,
#  'shuddered': <gensim.models.keyedvectors.Vocab at 0x129ad0f98>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x129ad09b0>,
#  'arrived': <gensim.models.keyedvectors.Vocab at 0x129ad0240>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x129ad07f0>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x129ad0048>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x129ad04a8>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x129ad0c18>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x129ad0208>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x129ad0320>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x129ad0198>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x129ad06a0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x129ad0c50>,
#  'good_reason': <gensim.models.keyedvectors.Vocab at 0x129ad0780>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x129ad0438>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x129ad0550>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x129ad0f28>,
#  'mixing': <gensim.models.keyedvectors.Vocab at 0x129ad07b8>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x129ad0e48>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x129ad0898>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x129ad08d0>,
#  'woke_up': <gensim.models.keyedvectors.Vocab at 0x129ad0b00>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x129ad0d68>,
#  'gray': <gensim.models.keyedvectors.Vocab at 0x129ad0080>,
#  'tuesday': <gensim.models.keyedvectors.Vocab at 0x129ad0668>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x129ad06d8>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x129ad0fd0>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x129ad0b38>,
#  'cloudy': <gensim.models.keyedvectors.Vocab at 0x129ad0da0>,
#  'sky_outside': <gensim.models.keyedvectors.Vocab at 0x129ad0588>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x129ad0390>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x129ad05f8>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x129ad0f60>,
#  'happening': <gensim.models.keyedvectors.Vocab at 0x129ad0b70>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x129ad02e8>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x129ad0c88>,
#  'hummed': <gensim.models.keyedvectors.Vocab at 0x129ad0470>,
#  'picked': <gensim.models.keyedvectors.Vocab at 0x12101dba8>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x12101dcf8>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x12101da58>,
#  'boring': <gensim.models.keyedvectors.Vocab at 0x12101dcc0>,
#  'tie': <gensim.models.keyedvectors.Vocab at 0x12101de48>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x12101dbe0>,
#  'happily': <gensim.models.keyedvectors.Vocab at 0x12101d8d0>,
#  'screaming': <gensim.models.keyedvectors.Vocab at 0x12101da90>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x12101da20>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x12101db70>,
#  'chair': <gensim.models.keyedvectors.Vocab at 0x12101dac8>,
#  'none_of': <gensim.models.keyedvectors.Vocab at 0x12101dc18>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x12101dd68>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x12101dc50>,
#  'tawny': <gensim.models.keyedvectors.Vocab at 0x12101d9e8>,
#  'owl': <gensim.models.keyedvectors.Vocab at 0x12101d908>,
#  'flutter': <gensim.models.keyedvectors.Vocab at 0x12101d978>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x12101dd30>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x12101d9b0>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x12101dda0>,
#  'half_past': <gensim.models.keyedvectors.Vocab at 0x12101ddd8>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x12101db00>,
#  'picked_up': <gensim.models.keyedvectors.Vocab at 0x12101d7b8>,
#  'briefcase': <gensim.models.keyedvectors.Vocab at 0x1222cbb00>,
#  'cheek': <gensim.models.keyedvectors.Vocab at 0x12229cba8>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x12229c668>,
#  'kiss': <gensim.models.keyedvectors.Vocab at 0x12229c5c0>,
#  'good_bye': <gensim.models.keyedvectors.Vocab at 0x12229cac8>,
#  'missed': <gensim.models.keyedvectors.Vocab at 0x12229c7b8>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x12229c278>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x12229c2e8>,
#  'tantrum': <gensim.models.keyedvectors.Vocab at 0x12229cf98>,
#  'throwing': <gensim.models.keyedvectors.Vocab at 0x12229c198>,
#  'walls': <gensim.models.keyedvectors.Vocab at 0x12229ca20>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x12229c8d0>,
#  'chortled': <gensim.models.keyedvectors.Vocab at 0x12229c3c8>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x12229c710>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x12229cda0>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x12229cd68>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x12229c588>,
#  'backed': <gensim.models.keyedvectors.Vocab at 0x12229c748>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x12229c0f0>,
#  'corner': <gensim.models.keyedvectors.Vocab at 0x12229c908>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x12229ca90>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x12229c080>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x12229c1d0>,
#  'peculiar': <gensim.models.keyedvectors.Vocab at 0x12229c4e0>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x12229cb70>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x12229cdd8>,
#  'map': <gensim.models.keyedvectors.Vocab at 0x12229ccf8>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x12229c780>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x12229c160>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x12229cd30>,
#  'jerked': <gensim.models.keyedvectors.Vocab at 0x12229c6a0>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x12229c358>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x12229c5f8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x12229ce48>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x12229c0b8>,
#  'tabby': <gensim.models.keyedvectors.Vocab at 0x12229c7f0>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x12229c240>,
#  'wasn_t': <gensim.models.keyedvectors.Vocab at 0x12229c4a8>,
#  'sight': <gensim.models.keyedvectors.Vocab at 0x12229c630>,
#  'have_been': <gensim.models.keyedvectors.Vocab at 0x12229c320>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x12229c208>,
#  'must_have': <gensim.models.keyedvectors.Vocab at 0x12229cb38>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x12229c6d8>,
#  'trick': <gensim.models.keyedvectors.Vocab at 0x12229cb00>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x12229cf60>,
#  'blinked': <gensim.models.keyedvectors.Vocab at 0x12229cc18>,
#  'stared_at': <gensim.models.keyedvectors.Vocab at 0x12229c048>,
#  'stared': <gensim.models.keyedvectors.Vocab at 0x12229ccc0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x12229c898>,
#  'drove': <gensim.models.keyedvectors.Vocab at 0x12229c940>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x12229ceb8>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x12229cbe0>,
#  'watched': <gensim.models.keyedvectors.Vocab at 0x12229c128>,
#  'mirror': <gensim.models.keyedvectors.Vocab at 0x12229c860>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x12229c978>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x12229cc88>,
#  'cats': <gensim.models.keyedvectors.Vocab at 0x12229ce10>,
#  'couldn_t': <gensim.models.keyedvectors.Vocab at 0x12229c518>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x12229c2b0>,
#  'signs': <gensim.models.keyedvectors.Vocab at 0x12229c400>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x12229c9e8>,
#  'himself': <gensim.models.keyedvectors.Vocab at 0x12229cf28>,
#  'shake': <gensim.models.keyedvectors.Vocab at 0x12229cfd0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x12229c470>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x12229cef0>,
#  'toward': <gensim.models.keyedvectors.Vocab at 0x12229ca58>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x12229cc50>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x12229c9b0>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x12229ce80>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x12229c438>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x12229c550>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x11feecc18>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x11feeca58>,
#  'edge_of': <gensim.models.keyedvectors.Vocab at 0x11feecf98>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x129ad4048>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x129ad4668>,
#  'something_else': <gensim.models.keyedvectors.Vocab at 0x129ad43c8>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x129ad4e80>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x129ad45f8>,
#  'traffic': <gensim.models.keyedvectors.Vocab at 0x129ad40b8>,
#  'jam': <gensim.models.keyedvectors.Vocab at 0x129ad4400>,
#  'help_noticing': <gensim.models.keyedvectors.Vocab at 0x129ad4ac8>,
#  'seemed': <gensim.models.keyedvectors.Vocab at 0x129ad4518>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x129ad4d30>,
#  'strangely': <gensim.models.keyedvectors.Vocab at 0x129ad4f60>,
#  'dressed': <gensim.models.keyedvectors.Vocab at 0x129ad4860>,
#  'cloaks': <gensim.models.keyedvectors.Vocab at 0x129ad4be0>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x129ad4358>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x129ad4278>,
#  'clothes': <gensim.models.keyedvectors.Vocab at 0x129ad47b8>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x129ad4198>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x129ad4080>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x129ad4dd8>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x129ad4240>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x129ad4a20>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x129ad4c88>,
#  'fashion': <gensim.models.keyedvectors.Vocab at 0x129ad4cf8>,
#  'fingers': <gensim.models.keyedvectors.Vocab at 0x129ad4128>,
#  'steering_wheel': <gensim.models.keyedvectors.Vocab at 0x129ad4f98>,
#  'eyes': <gensim.models.keyedvectors.Vocab at 0x129ad4a58>,
#  'fell': <gensim.models.keyedvectors.Vocab at 0x129ad4da0>,
#  'huddle': <gensim.models.keyedvectors.Vocab at 0x129ad4630>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x129ad4fd0>,
#  'weirdos': <gensim.models.keyedvectors.Vocab at 0x126d00fd0>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x126d00eb8>,
#  'close_by': <gensim.models.keyedvectors.Vocab at 0x126d008d0>,
#  'whispering': <gensim.models.keyedvectors.Vocab at 0x126d00390>,
#  'excitedly': <gensim.models.keyedvectors.Vocab at 0x129ad4908>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x129ad46d8>,
#  'enraged': <gensim.models.keyedvectors.Vocab at 0x129ad4f28>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x129ad4a90>,
#  'a_couple': <gensim.models.keyedvectors.Vocab at 0x129ad4710>,
#  'weren_t': <gensim.models.keyedvectors.Vocab at 0x129ad44a8>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x129ad4320>,
#  'older_than': <gensim.models.keyedvectors.Vocab at 0x129ad4cc0>,
#  'wearing': <gensim.models.keyedvectors.Vocab at 0x129ad4d68>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x129ad4b38>,
#  'emerald_green': <gensim.models.keyedvectors.Vocab at 0x129ad45c0>,
#  'cloak': <gensim.models.keyedvectors.Vocab at 0x129ad4780>,
#  'nerve': <gensim.models.keyedvectors.Vocab at 0x129ad4ba8>,
#  'struck': <gensim.models.keyedvectors.Vocab at 0x129ad41d0>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x129ad4588>,
#  'silly': <gensim.models.keyedvectors.Vocab at 0x129ad4e48>,
#  'these_people': <gensim.models.keyedvectors.Vocab at 0x129ad4c18>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x129ad4208>,
#  'collecting': <gensim.models.keyedvectors.Vocab at 0x129ad4b00>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x129ad4550>,
#  'would_be': <gensim.models.keyedvectors.Vocab at 0x129ad4940>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x129ad40f0>,
#  'a_few': <gensim.models.keyedvectors.Vocab at 0x129ad49e8>,
#  'minutes_later': <gensim.models.keyedvectors.Vocab at 0x129ad4160>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x129ad49b0>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x129ad42e8>,
#  'ninth': <gensim.models.keyedvectors.Vocab at 0x129ad4828>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x11f7265c0>,
#  'might_have': <gensim.models.keyedvectors.Vocab at 0x11f726780>,
#  'harder': <gensim.models.keyedvectors.Vocab at 0x11f726278>,
#  'concentrate': <gensim.models.keyedvectors.Vocab at 0x11f726e10>,
#  'owls': <gensim.models.keyedvectors.Vocab at 0x11f726dd8>,
#  'swooping': <gensim.models.keyedvectors.Vocab at 0x11f726f28>,
#  'broad': <gensim.models.keyedvectors.Vocab at 0x11f726e80>,
#  'daylight': <gensim.models.keyedvectors.Vocab at 0x11f726e48>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x11f726a90>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x11f726518>,
#  'pointed': <gensim.models.keyedvectors.Vocab at 0x11f726390>,
#  'gazed': <gensim.models.keyedvectors.Vocab at 0x11f7265f8>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x11f726d30>,
#  'mouthed': <gensim.models.keyedvectors.Vocab at 0x11f726ef0>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x11f7268d0>,
#  'sped': <gensim.models.keyedvectors.Vocab at 0x11f726a58>,
#  'overhead': <gensim.models.keyedvectors.Vocab at 0x11f726240>,
#  'never_seen': <gensim.models.keyedvectors.Vocab at 0x11f726fd0>,
#  'an_owl': <gensim.models.keyedvectors.Vocab at 0x11f726320>,
#  'nighttime': <gensim.models.keyedvectors.Vocab at 0x11f7266a0>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x11f726c18>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x11f726c88>,
#  'yelled': <gensim.models.keyedvectors.Vocab at 0x11f7260b8>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x11f7269b0>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x11f726668>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x11f7264e0>,
#  'telephone': <gensim.models.keyedvectors.Vocab at 0x11f726470>,
#  'calls': <gensim.models.keyedvectors.Vocab at 0x11f7267f0>,
#  'shouted': <gensim.models.keyedvectors.Vocab at 0x11f726400>,
#  'a_bit': <gensim.models.keyedvectors.Vocab at 0x11f726978>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x11f726208>,
#  'very_good': <gensim.models.keyedvectors.Vocab at 0x11f726048>,
#  'mood': <gensim.models.keyedvectors.Vocab at 0x11f726a20>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x11f726908>,
#  'lunchtime': <gensim.models.keyedvectors.Vocab at 0x11f726d68>,
#  'stretch': <gensim.models.keyedvectors.Vocab at 0x11f726898>,
#  'legs': <gensim.models.keyedvectors.Vocab at 0x11f726860>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x11f726ac8>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x11f7262b0>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x11f71dd30>,
#  'bun': <gensim.models.keyedvectors.Vocab at 0x11f71d710>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x11f71dc18>,
#  'forgotten': <gensim.models.keyedvectors.Vocab at 0x11f71dda0>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x11f71d320>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x11f71d390>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x11f71dfd0>,
#  'eyed': <gensim.models.keyedvectors.Vocab at 0x11f71d588>,
#  'angrily': <gensim.models.keyedvectors.Vocab at 0x11f71dba8>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x11f71d160>,
#  'uneasy': <gensim.models.keyedvectors.Vocab at 0x11f71de48>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x11f71d940>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x11f71d048>,
#  'tin': <gensim.models.keyedvectors.Vocab at 0x11f71da90>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x11f71db38>,
#  'clutching': <gensim.models.keyedvectors.Vocab at 0x11f71dc88>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x11f71df28>,
#  'caught': <gensim.models.keyedvectors.Vocab at 0x11f71d470>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x11f71d908>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x11f71d3c8>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x11f71d4a8>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x11f71d828>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x11f71dbe0>,
#  'harry': <gensim.models.keyedvectors.Vocab at 0x11f71d860>,
#  'stopped_dead': <gensim.models.keyedvectors.Vocab at 0x11f71d630>,
#  'flooded': <gensim.models.keyedvectors.Vocab at 0x11f71d7b8>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x11f71def0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x11f71d080>,
#  'dashed': <gensim.models.keyedvectors.Vocab at 0x11f71dc50>,
#  'hurried': <gensim.models.keyedvectors.Vocab at 0x11f71d2b0>,
#  'snapped': <gensim.models.keyedvectors.Vocab at 0x129acd8d0>,
#  'secretary': <gensim.models.keyedvectors.Vocab at 0x129acdd30>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x129acd518>,
#  'disturb': <gensim.models.keyedvectors.Vocab at 0x129acd5c0>,
#  'seized': <gensim.models.keyedvectors.Vocab at 0x129acd160>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x129acd898>,
#  'finished': <gensim.models.keyedvectors.Vocab at 0x129acdef0>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x129acdf98>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x129acd7f0>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x129acd860>,
#  'receiver': <gensim.models.keyedvectors.Vocab at 0x129acdb70>,
#  'stroked': <gensim.models.keyedvectors.Vocab at 0x129acd320>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x129acd978>,
#  'unusual': <gensim.models.keyedvectors.Vocab at 0x129acdfd0>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x129acde10>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x129acd198>,
#  'lots': <gensim.models.keyedvectors.Vocab at 0x129acdf28>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x129acd438>,
#  'nephew': <gensim.models.keyedvectors.Vocab at 0x129acdf60>,
#  'no_point': <gensim.models.keyedvectors.Vocab at 0x129acdda0>,
#  'worrying': <gensim.models.keyedvectors.Vocab at 0x129acdcf8>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x129acd780>,
#  'upset': <gensim.models.keyedvectors.Vocab at 0x129acd048>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x129acdeb8>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x129acd208>,
#  'blame': <gensim.models.keyedvectors.Vocab at 0x129acd908>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x129acdb00>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x129acd470>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x129acdb38>,
#  'building': <gensim.models.keyedvectors.Vocab at 0x129acde80>,
#  'five_o': <gensim.models.keyedvectors.Vocab at 0x129acd0f0>,
#  'clock': <gensim.models.keyedvectors.Vocab at 0x129acd400>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x129acd1d0>,
#  'worried': <gensim.models.keyedvectors.Vocab at 0x129acd3c8>,
#  'walked_straight': <gensim.models.keyedvectors.Vocab at 0x129acd9e8>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x129acddd8>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x129acd940>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x129acdd68>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x129acda90>,
#  'grunted': <gensim.models.keyedvectors.Vocab at 0x129acd748>,
#  'tiny': <gensim.models.keyedvectors.Vocab at 0x129acd240>,
#  'old_man': <gensim.models.keyedvectors.Vocab at 0x129acdc50>,
#  'stumbled': <gensim.models.keyedvectors.Vocab at 0x129acd390>,
#  'seconds_before': <gensim.models.keyedvectors.Vocab at 0x129acda20>,
#  'realized_that': <gensim.models.keyedvectors.Vocab at 0x129acd668>,
#  'violet': <gensim.models.keyedvectors.Vocab at 0x129acd6d8>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x129acd9b0>,
#  'knocked': <gensim.models.keyedvectors.Vocab at 0x129acde48>,
#  'ground': <gensim.models.keyedvectors.Vocab at 0x1222d20f0>,
#  'contrary': <gensim.models.keyedvectors.Vocab at 0x1222d2a90>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x1222d2780>,
#  'split': <gensim.models.keyedvectors.Vocab at 0x1222d2b38>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x11f73e278>,
#  'smile': <gensim.models.keyedvectors.Vocab at 0x11f73e400>,
#  'squeaky': <gensim.models.keyedvectors.Vocab at 0x11f73e898>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x11f73e0b8>,
#  'passersby': <gensim.models.keyedvectors.Vocab at 0x11f73ee48>,
#  'stare': <gensim.models.keyedvectors.Vocab at 0x11f73ea90>,
#  'don_t': <gensim.models.keyedvectors.Vocab at 0x11f73ef60>,
#  'my_dear': <gensim.models.keyedvectors.Vocab at 0x11f73e6a0>,
#  'sir': <gensim.models.keyedvectors.Vocab at 0x11f73e8d0>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x11f73e358>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x11f73e710>,
#  'know_who': <gensim.models.keyedvectors.Vocab at 0x11f73e160>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x11f73eeb8>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x11f73e4a8>,
#  'muggles': <gensim.models.keyedvectors.Vocab at 0x11f73eef0>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x11f73e860>,
#  'should_be': <gensim.models.keyedvectors.Vocab at 0x11f73ee80>,
#  'celebrating': <gensim.models.keyedvectors.Vocab at 0x11f73e0f0>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x11f73eda0>,
#  'hugged': <gensim.models.keyedvectors.Vocab at 0x11f73eba8>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x11f73e550>,
#  'walked': <gensim.models.keyedvectors.Vocab at 0x11f73e9b0>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x11f73efd0>,
#  'stood': <gensim.models.keyedvectors.Vocab at 0x11f73eac8>,
#  'rooted': <gensim.models.keyedvectors.Vocab at 0x11f73e518>,
#  'spot': <gensim.models.keyedvectors.Vocab at 0x11f73ef98>,
#  'had_been': <gensim.models.keyedvectors.Vocab at 0x11f73e2b0>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x11f73e3c8>,
#  'stranger': <gensim.models.keyedvectors.Vocab at 0x11f73e668>,
#  'muggle': <gensim.models.keyedvectors.Vocab at 0x121fa2780>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x121fa2240>,
#  'rattled': <gensim.models.keyedvectors.Vocab at 0x121fa25c0>,
#  'set_off': <gensim.models.keyedvectors.Vocab at 0x121fa2e10>,
#  'imagining': <gensim.models.keyedvectors.Vocab at 0x1222c5eb8>,
#  'hoped': <gensim.models.keyedvectors.Vocab at 0x1222c5f98>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x1222c51d0>,
#  'approve': <gensim.models.keyedvectors.Vocab at 0x1222c5da0>,
#  'imagination': <gensim.models.keyedvectors.Vocab at 0x1222c53c8>,
#  'pulled': <gensim.models.keyedvectors.Vocab at 0x1222c5d68>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x1222c5358>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x1222c5390>,
#  'spotted': <gensim.models.keyedvectors.Vocab at 0x1222c5198>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x1222c56a0>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x1222c50b8>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1222c5828>,
#  'markings_around': <gensim.models.keyedvectors.Vocab at 0x1222c5128>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x1222c55f8>,
#  'loudly': <gensim.models.keyedvectors.Vocab at 0x1222c59b0>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1222c5c18>,
#  'stern': <gensim.models.keyedvectors.Vocab at 0x1222c5710>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x1222c5ac8>,
#  'wondered': <gensim.models.keyedvectors.Vocab at 0x1222c5780>,
#  'trying_to': <gensim.models.keyedvectors.Vocab at 0x1222c5278>,
#  'pull_himself': <gensim.models.keyedvectors.Vocab at 0x1222c5940>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x1222c5a20>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x1222c5b00>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x1222c5630>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x1222c5f60>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x1222c5ef0>,
#  'dinner': <gensim.models.keyedvectors.Vocab at 0x1222c5438>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x1222c50f0>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x1222c5080>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x1222c59e8>,
#  'learned': <gensim.models.keyedvectors.Vocab at 0x1222c5dd8>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x1222c5550>,
#  'won_t': <gensim.models.keyedvectors.Vocab at 0x1222c5160>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x1222c52b0>,
#  'normally': <gensim.models.keyedvectors.Vocab at 0x1222c5470>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x1222c5a58>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x1222c5d30>,
#  'living_room': <gensim.models.keyedvectors.Vocab at 0x1222c5ba8>,
#  'catch': <gensim.models.keyedvectors.Vocab at 0x1222c5b70>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x1222c58d0>,
#  'evening': <gensim.models.keyedvectors.Vocab at 0x1222c5978>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x1222c54a8>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x1222c57b8>,
#  'bird': <gensim.models.keyedvectors.Vocab at 0x1222c5cc0>,
#  'watchers': <gensim.models.keyedvectors.Vocab at 0x1222c5e10>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x1222c5cf8>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x1222c5588>,
#  'behaving': <gensim.models.keyedvectors.Vocab at 0x1222c5860>,
#  'unusually': <gensim.models.keyedvectors.Vocab at 0x1222c5fd0>,
#  'hunt': <gensim.models.keyedvectors.Vocab at 0x1222c57f0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x1222c5a90>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1222c5b38>,
#  'hardly_ever': <gensim.models.keyedvectors.Vocab at 0x1222c5748>,
#  'hundreds_of': <gensim.models.keyedvectors.Vocab at 0x1222c5048>,
#  'sightings': <gensim.models.keyedvectors.Vocab at 0x1222c5908>,
#  'birds': <gensim.models.keyedvectors.Vocab at 0x1222c56d8>,
#  'flying': <gensim.models.keyedvectors.Vocab at 0x1222c5668>,
#  'every_direction': <gensim.models.keyedvectors.Vocab at 0x1222c52e8>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1222c5518>,
#  'sunrise': <gensim.models.keyedvectors.Vocab at 0x1222c5e80>,
#  'experts': <gensim.models.keyedvectors.Vocab at 0x1222c54e0>,
#  'unable_to': <gensim.models.keyedvectors.Vocab at 0x1222c5240>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x1222c5320>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x1222c5be0>,
#  'sleeping': <gensim.models.keyedvectors.Vocab at 0x11f727e48>,
#  'pattern': <gensim.models.keyedvectors.Vocab at 0x11f727b38>,
#  'allowed': <gensim.models.keyedvectors.Vocab at 0x11f7278d0>,
#  'grin': <gensim.models.keyedvectors.Vocab at 0x11f727da0>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x11f7272b0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x11f7277f0>,
#  'any_more': <gensim.models.keyedvectors.Vocab at 0x11f727a58>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x11f727ef0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x11f727710>,
#  'ted': <gensim.models.keyedvectors.Vocab at 0x11f727d30>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x11f727518>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x11f727400>,
#  'oddly': <gensim.models.keyedvectors.Vocab at 0x11f7270f0>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x11f7277b8>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x11f7279b0>,
#  'yorkshire': <gensim.models.keyedvectors.Vocab at 0x11f727dd8>,
#  'tell_me': <gensim.models.keyedvectors.Vocab at 0x11f727c50>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x11f727eb8>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x11f7274a8>,
#  'promised': <gensim.models.keyedvectors.Vocab at 0x11f727438>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x11f727cc0>,
#  've': <gensim.models.keyedvectors.Vocab at 0x11f727780>,
#  'downpour': <gensim.models.keyedvectors.Vocab at 0x11f727550>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x11f727748>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x11f727a20>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x11f727908>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x11f7274e0>,
#  'next_week': <gensim.models.keyedvectors.Vocab at 0x11f7272e8>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x11f727668>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x11f7276d8>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x11f727b00>,
#  'frozen': <gensim.models.keyedvectors.Vocab at 0x11f727048>,
#  'armchair': <gensim.models.keyedvectors.Vocab at 0x129ad52e8>,
#  'britain': <gensim.models.keyedvectors.Vocab at 0x129ad5668>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x129ad5a58>,
#  'whisper': <gensim.models.keyedvectors.Vocab at 0x129ad5c50>,
#  'carrying': <gensim.models.keyedvectors.Vocab at 0x129ad5b00>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x129ad5940>,
#  'cups': <gensim.models.keyedvectors.Vocab at 0x129ad5a20>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x129ad5780>,
#  'cleared': <gensim.models.keyedvectors.Vocab at 0x129ad5240>,
#  'his_throat': <gensim.models.keyedvectors.Vocab at 0x129ad5e10>,
#  'nervously': <gensim.models.keyedvectors.Vocab at 0x129ad5c88>,
#  'er': <gensim.models.keyedvectors.Vocab at 0x129ad5550>,
#  'petunia': <gensim.models.keyedvectors.Vocab at 0x129ad5f28>,
#  'dear': <gensim.models.keyedvectors.Vocab at 0x129ad5860>,
#  'haven_t': <gensim.models.keyedvectors.Vocab at 0x129ad55c0>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x129ad5908>,
#  'lately': <gensim.models.keyedvectors.Vocab at 0x129ad56a0>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x129ad5fd0>,
#  'shocked': <gensim.models.keyedvectors.Vocab at 0x129ad5a90>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x129ad5128>,
#  'sharply': <gensim.models.keyedvectors.Vocab at 0x129ad5198>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x129ad53c8>,
#  'mumbled': <gensim.models.keyedvectors.Vocab at 0x129ad5400>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x129ad5d30>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x129ad50f0>,
#  'crowd': <gensim.models.keyedvectors.Vocab at 0x129ad59b0>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x129ad5c18>,
#  'pursed': <gensim.models.keyedvectors.Vocab at 0x129ad5278>,
#  'lips': <gensim.models.keyedvectors.Vocab at 0x129ad5cf8>,
#  'wondered_whether': <gensim.models.keyedvectors.Vocab at 0x129ad52b0>,
#  'dared': <gensim.models.keyedvectors.Vocab at 0x129ad5358>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x129ad5be0>,
#  'decided': <gensim.models.keyedvectors.Vocab at 0x129ad5e48>,
#  'dare': <gensim.models.keyedvectors.Vocab at 0x129ad57b8>,
#  'casually': <gensim.models.keyedvectors.Vocab at 0x129ad54a8>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x129ad5b70>,
#  'wouldn_t': <gensim.models.keyedvectors.Vocab at 0x129ad5390>,
#  'i_suppose': <gensim.models.keyedvectors.Vocab at 0x129ad5160>,
#  'stiffly': <gensim.models.keyedvectors.Vocab at 0x129ad5dd8>,
#  'isn_t': <gensim.models.keyedvectors.Vocab at 0x129ad50b8>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x129ad54e0>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x129ad51d0>,
#  'ask_me': <gensim.models.keyedvectors.Vocab at 0x129ad5f98>,
#  'oh_yes': <gensim.models.keyedvectors.Vocab at 0x129ad5630>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x129ad5d68>,
#  'sinking': <gensim.models.keyedvectors.Vocab at 0x129ad5ac8>,
#  'horribly': <gensim.models.keyedvectors.Vocab at 0x129ad5588>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x129ad5470>,
#  'another_word': <gensim.models.keyedvectors.Vocab at 0x129ad56d8>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x129ad5898>,
#  'upstairs': <gensim.models.keyedvectors.Vocab at 0x129ad5cc0>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x129ad55f8>,
#  'bathroom': <gensim.models.keyedvectors.Vocab at 0x129ad5710>,
#  'crept': <gensim.models.keyedvectors.Vocab at 0x129ad5080>,
#  'bedroom': <gensim.models.keyedvectors.Vocab at 0x12101e898>,
#  'peered': <gensim.models.keyedvectors.Vocab at 0x12101eda0>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x12101ea90>,
#  'staring': <gensim.models.keyedvectors.Vocab at 0x12101e358>,
#  'as_though': <gensim.models.keyedvectors.Vocab at 0x12101e710>,
#  'waiting_for': <gensim.models.keyedvectors.Vocab at 0x12101eb70>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x1222cff28>,
#  'pair_of': <gensim.models.keyedvectors.Vocab at 0x1222cfac8>,
#  'fell_asleep': <gensim.models.keyedvectors.Vocab at 0x1222cff60>,
#  'quickly': <gensim.models.keyedvectors.Vocab at 0x1222cf5f8>,
#  'lay_awake': <gensim.models.keyedvectors.Vocab at 0x1222cf978>,
#  'turning': <gensim.models.keyedvectors.Vocab at 0x1222a3748>,
#  'comforting': <gensim.models.keyedvectors.Vocab at 0x1222a30f0>,
#  'even_if': <gensim.models.keyedvectors.Vocab at 0x1222a3c50>,
#  'no_reason': <gensim.models.keyedvectors.Vocab at 0x12228c668>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x12228c390>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x12228c9e8>,
#  'mixed_up': <gensim.models.keyedvectors.Vocab at 0x12228c940>,
#  'might_be': <gensim.models.keyedvectors.Vocab at 0x12228cf28>,
#  'yawned': <gensim.models.keyedvectors.Vocab at 0x12228c550>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x12228c588>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x12228cdd8>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x12228c630>,
#  'drifting': <gensim.models.keyedvectors.Vocab at 0x12228c400>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x12228c198>,
#  'showing': <gensim.models.keyedvectors.Vocab at 0x12228c470>,
#  'no_sign': <gensim.models.keyedvectors.Vocab at 0x12228cef0>,
#  'statue': <gensim.models.keyedvectors.Vocab at 0x12228c978>,
#  'eyes_fixed': <gensim.models.keyedvectors.Vocab at 0x12228c208>,
#  'unblinkingly': <gensim.models.keyedvectors.Vocab at 0x12228cc50>,
#  'far_corner': <gensim.models.keyedvectors.Vocab at 0x12228c320>,
#  'quiver': <gensim.models.keyedvectors.Vocab at 0x12228c780>,
#  'door_slammed': <gensim.models.keyedvectors.Vocab at 0x12228c6d8>,
#  'nor': <gensim.models.keyedvectors.Vocab at 0x12228c7b8>,
#  'swooped': <gensim.models.keyedvectors.Vocab at 0x12228c748>,
#  'midnight': <gensim.models.keyedvectors.Vocab at 0x12228cfd0>,
#  'appeared': <gensim.models.keyedvectors.Vocab at 0x12228c8d0>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x12228ce10>,
#  'silently': <gensim.models.keyedvectors.Vocab at 0x12228c438>,
#  'popped': <gensim.models.keyedvectors.Vocab at 0x12228cb00>,
#  'tail': <gensim.models.keyedvectors.Vocab at 0x12228c7f0>,
#  'twitched': <gensim.models.keyedvectors.Vocab at 0x12228cb38>,
#  'eyes_narrowed': <gensim.models.keyedvectors.Vocab at 0x12228c0b8>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x12228ccf8>,
#  'tall_thin': <gensim.models.keyedvectors.Vocab at 0x12228cba8>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x12228c710>,
#  'judging_by': <gensim.models.keyedvectors.Vocab at 0x12228c860>,
#  'silver': <gensim.models.keyedvectors.Vocab at 0x12228c358>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x12228cc18>,
#  'beard': <gensim.models.keyedvectors.Vocab at 0x12228c5f8>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x12228cf60>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x12228cbe0>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x12228c5c0>,
#  'tuck': <gensim.models.keyedvectors.Vocab at 0x12228c898>,
#  'belt': <gensim.models.keyedvectors.Vocab at 0x12228c828>,
#  'robes': <gensim.models.keyedvectors.Vocab at 0x12228c128>,
#  'purple': <gensim.models.keyedvectors.Vocab at 0x12228cb70>,
#  'swept': <gensim.models.keyedvectors.Vocab at 0x12228cd30>,
#  'buckled': <gensim.models.keyedvectors.Vocab at 0x12228c2e8>,
#  'boots': <gensim.models.keyedvectors.Vocab at 0x12228c080>,
#  'blue_eyes': <gensim.models.keyedvectors.Vocab at 0x12228cd68>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x12228c4a8>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x12228c4e0>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x12228ca90>,
#  'half_moon': <gensim.models.keyedvectors.Vocab at 0x12228ceb8>,
#  'spectacles': <gensim.models.keyedvectors.Vocab at 0x12228c048>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x12228c518>,
#  'crooked': <gensim.models.keyedvectors.Vocab at 0x12228cac8>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x12228cf98>,
#  'at_least': <gensim.models.keyedvectors.Vocab at 0x12228ca58>,
#  'albus_dumbledore': <gensim.models.keyedvectors.Vocab at 0x12228c908>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x12228c0f0>,
#  'unwelcome': <gensim.models.keyedvectors.Vocab at 0x12228ca20>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x12228c278>,
#  'rummaging': <gensim.models.keyedvectors.Vocab at 0x12228c1d0>,
#  'being_watched': <gensim.models.keyedvectors.Vocab at 0x12228ce48>,
#  'still_staring': <gensim.models.keyedvectors.Vocab at 0x12228c6a0>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x12228c160>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x12228cc88>,
#  'some_reason': <gensim.models.keyedvectors.Vocab at 0x12228ccc0>,
#  'chuckled': <gensim.models.keyedvectors.Vocab at 0x12228c2b0>,
#  'muttered': <gensim.models.keyedvectors.Vocab at 0x12228c9b0>,
#  'should_have': <gensim.models.keyedvectors.Vocab at 0x12228ce80>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x12228cda0>,
#  'inside_pocket': <gensim.models.keyedvectors.Vocab at 0x12228c240>,
#  'cigarette': <gensim.models.keyedvectors.Vocab at 0x12228fac8>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x12228f668>,
#  'flicked': <gensim.models.keyedvectors.Vocab at 0x12228f908>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x12228f6d8>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x12228f5f8>,
#  'clicked': <gensim.models.keyedvectors.Vocab at 0x12228f588>,
#  'nearest': <gensim.models.keyedvectors.Vocab at 0x12228fc88>,
#  'lamp': <gensim.models.keyedvectors.Vocab at 0x12228f198>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x12228f048>,
#  'flickered': <gensim.models.keyedvectors.Vocab at 0x12228f9e8>,
#  'darkness': <gensim.models.keyedvectors.Vocab at 0x12228fa58>,
#  'twelve': <gensim.models.keyedvectors.Vocab at 0x12228f9b0>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x12228fdd8>,
#  'outer': <gensim.models.keyedvectors.Vocab at 0x12228fd68>,
#  'lights': <gensim.models.keyedvectors.Vocab at 0x12228f2e8>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x12228f4e0>,
#  'distance': <gensim.models.keyedvectors.Vocab at 0x12228fba8>,
#  'beady': <gensim.models.keyedvectors.Vocab at 0x12228f240>,
#  'be_able': <gensim.models.keyedvectors.Vocab at 0x12228fcf8>,
#  'pavement': <gensim.models.keyedvectors.Vocab at 0x12228fa20>,
#  'dumbledore': <gensim.models.keyedvectors.Vocab at 0x12228f978>,
#  'slipped': <gensim.models.keyedvectors.Vocab at 0x12228fbe0>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x12228f748>,
#  'sat_down': <gensim.models.keyedvectors.Vocab at 0x12228f390>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x12228f2b0>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x12228f7f0>,
#  'fancy': <gensim.models.keyedvectors.Vocab at 0x12228f8d0>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x12228f6a0>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x12228f828>,
#  'professor_mcgonagall': <gensim.models.keyedvectors.Vocab at 0x12228ff98>,
#  'smiling': <gensim.models.keyedvectors.Vocab at 0x12228f940>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x12228f0b8>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x12228f780>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x12228f550>,
#  'square': <gensim.models.keyedvectors.Vocab at 0x12228fc18>,
#  'glasses': <gensim.models.keyedvectors.Vocab at 0x12228f5c0>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x12228f898>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x12228f438>,
#  'markings': <gensim.models.keyedvectors.Vocab at 0x12228f128>,
#  'emerald': <gensim.models.keyedvectors.Vocab at 0x12228fa90>,
#  'black_hair': <gensim.models.keyedvectors.Vocab at 0x12228f358>,
#  'drawn': <gensim.models.keyedvectors.Vocab at 0x12228f518>,
#  'tight': <gensim.models.keyedvectors.Vocab at 0x12228fe48>,
#  'distinctly': <gensim.models.keyedvectors.Vocab at 0x12228fcc0>,
#  'ruffled': <gensim.models.keyedvectors.Vocab at 0x12228f0f0>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x12228ffd0>,
#  'professor': <gensim.models.keyedvectors.Vocab at 0x12228f208>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x12228f320>,
#  'stiff': <gensim.models.keyedvectors.Vocab at 0x12228fb00>,
#  'brick': <gensim.models.keyedvectors.Vocab at 0x12228f7b8>,
#  'a_dozen': <gensim.models.keyedvectors.Vocab at 0x12228fb38>,
#  'parties': <gensim.models.keyedvectors.Vocab at 0x12228f278>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x12228fc50>,
#  'sniffed': <gensim.models.keyedvectors.Vocab at 0x12228f4a8>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x12228ff28>,
#  'all_right': <gensim.models.keyedvectors.Vocab at 0x12228f860>,
#  'impatiently': <gensim.models.keyedvectors.Vocab at 0x12228feb8>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x12228f470>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x12228f710>,
#  'they_re': <gensim.models.keyedvectors.Vocab at 0x12228ff60>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x12228f1d0>,
#  'bound': <gensim.models.keyedvectors.Vocab at 0x12228fe80>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x12228fb70>,
#  'll_bet': <gensim.models.keyedvectors.Vocab at 0x12228f080>,
#  'dedalus_diggle': <gensim.models.keyedvectors.Vocab at 0x11f731588>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x11f731390>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x11f731b00>,
#  'can_t': <gensim.models.keyedvectors.Vocab at 0x11f731c18>,
#  'gently': <gensim.models.keyedvectors.Vocab at 0x11f731a90>,
#  'we_ve': <gensim.models.keyedvectors.Vocab at 0x11f731a58>,
#  'precious': <gensim.models.keyedvectors.Vocab at 0x11f731358>,
#  'celebrate': <gensim.models.keyedvectors.Vocab at 0x11f731780>,
#  'eleven_years': <gensim.models.keyedvectors.Vocab at 0x11f7319e8>,
#  'irritably': <gensim.models.keyedvectors.Vocab at 0x11f731e10>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x11f731ac8>,
#  'heads': <gensim.models.keyedvectors.Vocab at 0x11f731cf8>,
#  'downright': <gensim.models.keyedvectors.Vocab at 0x11f731320>,
#  'careless': <gensim.models.keyedvectors.Vocab at 0x11f731208>,
#  'streets': <gensim.models.keyedvectors.Vocab at 0x11f731828>,
#  'rumors': <gensim.models.keyedvectors.Vocab at 0x11f731ba8>,
#  'threw': <gensim.models.keyedvectors.Vocab at 0x11f7319b0>,
#  'sharp': <gensim.models.keyedvectors.Vocab at 0x11f7316d8>,
#  'sideways': <gensim.models.keyedvectors.Vocab at 0x11f7312b0>,
#  'glance_at': <gensim.models.keyedvectors.Vocab at 0x11f7315c0>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x11f731860>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x11f7317f0>,
#  'disappeared': <gensim.models.keyedvectors.Vocab at 0x11f7316a0>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x11f731e48>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x11f731cc0>,
#  'certainly': <gensim.models.keyedvectors.Vocab at 0x11f731048>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x11f7313c8>,
#  'thankful': <gensim.models.keyedvectors.Vocab at 0x129acca90>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x129acccf8>,
#  'lemon': <gensim.models.keyedvectors.Vocab at 0x129acc588>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x129acc9e8>,
#  'kind_of': <gensim.models.keyedvectors.Vocab at 0x129acc3c8>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x129acc320>,
#  'i_m': <gensim.models.keyedvectors.Vocab at 0x129acc898>,
#  'fond': <gensim.models.keyedvectors.Vocab at 0x129acce10>,
#  'coldly': <gensim.models.keyedvectors.Vocab at 0x129acc438>,
#  'drops': <gensim.models.keyedvectors.Vocab at 0x129acc710>,
#  'surely': <gensim.models.keyedvectors.Vocab at 0x129accbe0>,
#  'sensible': <gensim.models.keyedvectors.Vocab at 0x129accac8>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x129acc5f8>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x129acc6d8>,
#  'persuade': <gensim.models.keyedvectors.Vocab at 0x129acc630>,
#  'proper': <gensim.models.keyedvectors.Vocab at 0x129acc6a0>,
#  'voldemort': <gensim.models.keyedvectors.Vocab at 0x129accd68>,
#  'flinched': <gensim.models.keyedvectors.Vocab at 0x129acc7b8>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x129accf28>,
#  'confusing': <gensim.models.keyedvectors.Vocab at 0x129acc978>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x129acc8d0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x129accdd8>,
#  'frightened': <gensim.models.keyedvectors.Vocab at 0x129acc780>,
#  'sounding': <gensim.models.keyedvectors.Vocab at 0x129acc5c0>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x129acc940>,
#  'exasperated': <gensim.models.keyedvectors.Vocab at 0x129acc748>,
#  'admiring': <gensim.models.keyedvectors.Vocab at 0x129accf60>,
#  're': <gensim.models.keyedvectors.Vocab at 0x129acc550>,
#  'everyone_knows': <gensim.models.keyedvectors.Vocab at 0x129acce80>,
#  'only_one': <gensim.models.keyedvectors.Vocab at 0x129accf98>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x129accc18>,
#  'dumbledore_calmly': <gensim.models.keyedvectors.Vocab at 0x129acc240>,
#  'powers': <gensim.models.keyedvectors.Vocab at 0x129acc0f0>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x129acc0b8>,
#  'noble': <gensim.models.keyedvectors.Vocab at 0x129acc358>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x129accef0>,
#  'lucky': <gensim.models.keyedvectors.Vocab at 0x129acc400>,
#  'blushed': <gensim.models.keyedvectors.Vocab at 0x129acccc0>,
#  'madam_pomfrey': <gensim.models.keyedvectors.Vocab at 0x129acc278>,
#  'told_me': <gensim.models.keyedvectors.Vocab at 0x129accb38>,
#  'liked': <gensim.models.keyedvectors.Vocab at 0x129acc2b0>,
#  'earmuffs': <gensim.models.keyedvectors.Vocab at 0x129acc470>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x129accda0>,
#  'stopped': <gensim.models.keyedvectors.Vocab at 0x129acc4e0>,
#  'reached': <gensim.models.keyedvectors.Vocab at 0x129acc7f0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x129accb70>,
#  'anxious': <gensim.models.keyedvectors.Vocab at 0x129acc1d0>,
#  'discuss': <gensim.models.keyedvectors.Vocab at 0x129accc50>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x129accfd0>,
#  'waiting': <gensim.models.keyedvectors.Vocab at 0x129accd30>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x129acca20>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x129acc390>,
#  'neither': <gensim.models.keyedvectors.Vocab at 0x129accc88>,
#  'fixed': <gensim.models.keyedvectors.Vocab at 0x129acc828>,
#  'piercing': <gensim.models.keyedvectors.Vocab at 0x129acc198>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x129acc860>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x129acc2e8>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x129acc518>,
#  'choosing': <gensim.models.keyedvectors.Vocab at 0x11f732588>,
#  'did_not': <gensim.models.keyedvectors.Vocab at 0x11f732358>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x11f732cc0>,
#  'pressed': <gensim.models.keyedvectors.Vocab at 0x11f732860>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x11f732048>,
#  'last_night': <gensim.models.keyedvectors.Vocab at 0x11f732ba8>,
#  'godric_s': <gensim.models.keyedvectors.Vocab at 0x11f732e48>,
#  'hollow': <gensim.models.keyedvectors.Vocab at 0x11f732668>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x11f732d68>,
#  'rumor': <gensim.models.keyedvectors.Vocab at 0x11f7322b0>,
#  'lily': <gensim.models.keyedvectors.Vocab at 0x11f732940>,
#  'james_potter': <gensim.models.keyedvectors.Vocab at 0x11f732f60>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x11f732908>,
#  'bowed': <gensim.models.keyedvectors.Vocab at 0x11f732128>,
#  'gasped': <gensim.models.keyedvectors.Vocab at 0x11f7327f0>,
#  'james': <gensim.models.keyedvectors.Vocab at 0x11f7320b8>,
#  'patted': <gensim.models.keyedvectors.Vocab at 0x11f732080>,
#  'shoulder': <gensim.models.keyedvectors.Vocab at 0x11f732898>,
#  'heavily': <gensim.models.keyedvectors.Vocab at 0x11f732550>,
#  'trembled': <gensim.models.keyedvectors.Vocab at 0x11f732c88>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x11f732390>,
#  'knows': <gensim.models.keyedvectors.Vocab at 0x11f7325f8>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x11f732e80>,
#  'somehow': <gensim.models.keyedvectors.Vocab at 0x11f732d30>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x11f732630>,
#  'nodded': <gensim.models.keyedvectors.Vocab at 0x11f732978>,
#  'glumly': <gensim.models.keyedvectors.Vocab at 0x11f732fd0>,
#  'faltered': <gensim.models.keyedvectors.Vocab at 0x11f7320f0>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x11f732470>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x11f732e10>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x11f732400>,
#  'survive': <gensim.models.keyedvectors.Vocab at 0x11f7329e8>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x11f732dd8>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x11f732f98>,
#  'pulled_out': <gensim.models.keyedvectors.Vocab at 0x11f732c18>,
#  'lace': <gensim.models.keyedvectors.Vocab at 0x11f732cf8>,
#  'handkerchief': <gensim.models.keyedvectors.Vocab at 0x11f7323c8>,
#  'dabbed': <gensim.models.keyedvectors.Vocab at 0x11f732ef0>,
#  'beneath': <gensim.models.keyedvectors.Vocab at 0x11f7321d0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x11f732a58>,
#  'sniff': <gensim.models.keyedvectors.Vocab at 0x11f7325c0>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x11f7326d8>,
#  'golden': <gensim.models.keyedvectors.Vocab at 0x11ece6438>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x11ece67b8>,
#  'pocket': <gensim.models.keyedvectors.Vocab at 0x129ad80f0>,
#  'examined': <gensim.models.keyedvectors.Vocab at 0x129ad86d8>,
#  'very_odd': <gensim.models.keyedvectors.Vocab at 0x129ad84e0>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x129ad8cc0>,
#  'numbers': <gensim.models.keyedvectors.Vocab at 0x129ad8978>,
#  'planets': <gensim.models.keyedvectors.Vocab at 0x129ad8b70>,
#  'moving': <gensim.models.keyedvectors.Vocab at 0x129ad8668>,
#  'edge': <gensim.models.keyedvectors.Vocab at 0x129ad8f98>,
#  'hagrid': <gensim.models.keyedvectors.Vocab at 0x129ad8940>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x129ad8e10>,
#  'suppose': <gensim.models.keyedvectors.Vocab at 0x129ad8278>,
#  're_going': <gensim.models.keyedvectors.Vocab at 0x129ad8c88>,
#  'places': <gensim.models.keyedvectors.Vocab at 0x129ad8710>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x129ad8860>,
#  'aunt': <gensim.models.keyedvectors.Vocab at 0x129ad8ba8>,
#  'uncle': <gensim.models.keyedvectors.Vocab at 0x129ad86a0>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x129ad8b38>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x129ad8dd8>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x129ad80b8>,
#  'cried': <gensim.models.keyedvectors.Vocab at 0x129ad8a90>,
#  'jumping': <gensim.models.keyedvectors.Vocab at 0x129ad8828>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x129ad81d0>,
#  'pointing_at': <gensim.models.keyedvectors.Vocab at 0x129ad8400>,
#  've_been': <gensim.models.keyedvectors.Vocab at 0x129ad8748>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x129ad84a8>,
#  've_got': <gensim.models.keyedvectors.Vocab at 0x129ad8e80>,
#  'kicking': <gensim.models.keyedvectors.Vocab at 0x129ad8eb8>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x129ad8588>,
#  'sweets': <gensim.models.keyedvectors.Vocab at 0x129ad88d0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x129ad8a58>,
#  'firmly': <gensim.models.keyedvectors.Vocab at 0x129ad8ac8>,
#  'will_be': <gensim.models.keyedvectors.Vocab at 0x129ad8438>,
#  'able_to': <gensim.models.keyedvectors.Vocab at 0x129ad8630>,
#  'older': <gensim.models.keyedvectors.Vocab at 0x129ad8c50>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x129ad8be0>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x129ad83c8>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x129ad8a20>,
#  'faintly': <gensim.models.keyedvectors.Vocab at 0x129ad89b0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x129ad8550>,
#  'll_be': <gensim.models.keyedvectors.Vocab at 0x129ad8f28>,
#  'famous': <gensim.models.keyedvectors.Vocab at 0x129ad8518>,
#  'legend': <gensim.models.keyedvectors.Vocab at 0x129ad8208>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x129ad85c0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x129ad85f8>,
#  'books': <gensim.models.keyedvectors.Vocab at 0x129ad8c18>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x129ad8390>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x129ad8908>,
#  'very_seriously': <gensim.models.keyedvectors.Vocab at 0x129ad8da0>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x129ad8cf8>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x129ad8e48>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x129ad8f60>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x129ad8160>,
#  'how_much': <gensim.models.keyedvectors.Vocab at 0x129ad8358>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x129ad82e8>,
#  'away_from': <gensim.models.keyedvectors.Vocab at 0x129ad8b00>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x129ad87f0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x129ad8d30>,
#  'opened': <gensim.models.keyedvectors.Vocab at 0x11ff04ef0>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x11ff04978>,
#  'swallowed': <gensim.models.keyedvectors.Vocab at 0x11ff04908>,
#  'yes_yes': <gensim.models.keyedvectors.Vocab at 0x11ff046a0>,
#  'of_course': <gensim.models.keyedvectors.Vocab at 0x11ff044e0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x11ff04fd0>,
#  'hiding': <gensim.models.keyedvectors.Vocab at 0x11ff04c88>,
#  'underneath': <gensim.models.keyedvectors.Vocab at 0x11ff04f28>,
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x11ff04f98>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x11ff04518>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x11ff04898>,
#  'my_life': <gensim.models.keyedvectors.Vocab at 0x11ff04710>,
#  'grudgingly': <gensim.models.keyedvectors.Vocab at 0x11ff040b8>,
#  'pretend': <gensim.models.keyedvectors.Vocab at 0x11ff04da0>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x11ff04a58>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x11ff04c18>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x11ff04e48>,
#  'rumbling': <gensim.models.keyedvectors.Vocab at 0x11f722e48>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x11f722b00>,
#  'silence': <gensim.models.keyedvectors.Vocab at 0x11f722c88>,
#  'grew': <gensim.models.keyedvectors.Vocab at 0x11f722eb8>,
#  'steadily': <gensim.models.keyedvectors.Vocab at 0x11f722d68>,
#  'louder': <gensim.models.keyedvectors.Vocab at 0x11f722ef0>,
#  'swelled': <gensim.models.keyedvectors.Vocab at 0x11f722828>,
#  'roar': <gensim.models.keyedvectors.Vocab at 0x11f722400>,
#  'sky': <gensim.models.keyedvectors.Vocab at 0x11f722c50>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x11f7224e0>,
#  'motorcycle': <gensim.models.keyedvectors.Vocab at 0x11f722748>,
#  'landed': <gensim.models.keyedvectors.Vocab at 0x11f722a90>,
#  'in_front': <gensim.models.keyedvectors.Vocab at 0x11f722908>,
#  'tall': <gensim.models.keyedvectors.Vocab at 0x11f722438>,
#  'five_times': <gensim.models.keyedvectors.Vocab at 0x11f722240>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x11f7227b8>,
#  'be_allowed': <gensim.models.keyedvectors.Vocab at 0x11f722860>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x11f722518>,
#  'bushy': <gensim.models.keyedvectors.Vocab at 0x11f722160>,
#  'hid': <gensim.models.keyedvectors.Vocab at 0x11f7222e8>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x11f722d30>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x11f7228d0>,
#  'lids': <gensim.models.keyedvectors.Vocab at 0x11f7222b0>,
#  'leather': <gensim.models.keyedvectors.Vocab at 0x11f722080>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x11f722898>,
#  'vast': <gensim.models.keyedvectors.Vocab at 0x11f722f98>,
#  'muscular': <gensim.models.keyedvectors.Vocab at 0x11f722cc0>,
#  ...}

# %%
model.similarity('ron', 'hermione')
# Out:
# /Users/isthatyoung/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.8581412

# %%
# Out:
# harry is related to brave, as crookshanks is related to ron
# /Users/isthatyoung/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   """
# 'crookshanks'

# %%
model.most_similar_cosmul('snape')
# Out:
# /Users/isthatyoung/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   """Entry point for launching an IPython kernel.
# [('malfoy', 0.8386757969856262),
#  ('dumbledore', 0.8284427523612976),
#  ('karkaroff', 0.8116424679756165),
#  ('severus', 0.8057114481925964),
#  ('draco', 0.8040138483047485),
#  ('voldemort', 0.8037510514259338),
#  ('umbridge', 0.8010824918746948),
#  ('professor', 0.7865403294563293),
#  ('moody', 0.7865027189254761),
#  ('he', 0.7821281552314758)]

# %%
model.most_similar_cosmul('voldemort')
# Out:
# /Users/isthatyoung/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   """Entry point for launching an IPython kernel.
# [('lord', 0.8760039806365967),
#  ('dumbledore', 0.8169885277748108),
#  ('lord_voldemort', 0.8068181872367859),
#  ('he', 0.8056886196136475),
#  ('snape', 0.8037510514259338),
#  ('wormtail', 0.7862421274185181),
#  ('speak_parseltongue', 0.7860992550849915),
#  ('without_knowing', 0.7852047085762024),
#  ('nobody_else', 0.7844182848930359),
#  ('even_worse', 0.7842920422554016)]

# %%
# Out:
# {'the_boy': <gensim.models.keyedvectors.Vocab at 0x126b46e80>,
#  'who_lived': <gensim.models.keyedvectors.Vocab at 0x125aa96d8>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x125aa96a0>,
#  'and_mrs': <gensim.models.keyedvectors.Vocab at 0x125aa98d0>,
#  'dursley': <gensim.models.keyedvectors.Vocab at 0x125aa9c18>,
#  'of_number': <gensim.models.keyedvectors.Vocab at 0x125aa9828>,
#  'four_privet': <gensim.models.keyedvectors.Vocab at 0x125aa9cf8>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x125aa94e0>,
#  'to_say': <gensim.models.keyedvectors.Vocab at 0x125aa9f98>,
#  'that_they': <gensim.models.keyedvectors.Vocab at 0x125aa9a20>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x125aa9438>,
#  'thank_you': <gensim.models.keyedvectors.Vocab at 0x125aa9da0>,
#  'very_much': <gensim.models.keyedvectors.Vocab at 0x125aa97f0>,
#  'they_were': <gensim.models.keyedvectors.Vocab at 0x125aa92e8>,
#  'the_last': <gensim.models.keyedvectors.Vocab at 0x125aa9a90>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x125aa91d0>,
#  'you_d': <gensim.models.keyedvectors.Vocab at 0x125aa95c0>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x125aa94a8>,
#  'to_be': <gensim.models.keyedvectors.Vocab at 0x125aa9c50>,
#  'involved_in': <gensim.models.keyedvectors.Vocab at 0x125aa9d68>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x125aa9240>,
#  'mysterious': <gensim.models.keyedvectors.Vocab at 0x125aa9710>,
#  'because_they': <gensim.models.keyedvectors.Vocab at 0x125aa9b38>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x125aa9cc0>,
#  'didn_t': <gensim.models.keyedvectors.Vocab at 0x125aa9898>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x125aa9978>,
#  'with_such': <gensim.models.keyedvectors.Vocab at 0x125aa9d30>,
#  'nonsense': <gensim.models.keyedvectors.Vocab at 0x125aa9e48>,
#  'mr_dursley': <gensim.models.keyedvectors.Vocab at 0x125aa9e10>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x125aa9fd0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x125aa9f28>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x125a96710>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x125a96a58>,
#  'which_made': <gensim.models.keyedvectors.Vocab at 0x125a96c18>,
#  'drills': <gensim.models.keyedvectors.Vocab at 0x125a96f28>,
#  'he_was': <gensim.models.keyedvectors.Vocab at 0x125a96668>,
#  'a_big': <gensim.models.keyedvectors.Vocab at 0x125a97048>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x125a970b8>,
#  'hardly_any': <gensim.models.keyedvectors.Vocab at 0x125a970f0>,
#  'neck': <gensim.models.keyedvectors.Vocab at 0x125a97128>,
#  'although_he': <gensim.models.keyedvectors.Vocab at 0x125a97160>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x125a97198>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x125a971d0>,
#  'a_very': <gensim.models.keyedvectors.Vocab at 0x125a97208>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x125a97240>,
#  'mustache': <gensim.models.keyedvectors.Vocab at 0x125a97278>,
#  'mrs_dursley': <gensim.models.keyedvectors.Vocab at 0x125a972b0>,
#  'thin': <gensim.models.keyedvectors.Vocab at 0x125a972e8>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x125a97320>,
#  'blonde': <gensim.models.keyedvectors.Vocab at 0x125a97358>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x125a97390>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x125a973c8>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x125a97400>,
#  'the_usual': <gensim.models.keyedvectors.Vocab at 0x125a97438>,
#  'amount_of': <gensim.models.keyedvectors.Vocab at 0x125a97470>,
#  'came_in': <gensim.models.keyedvectors.Vocab at 0x125a974a8>,
#  'as_she': <gensim.models.keyedvectors.Vocab at 0x125a974e0>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x125a97518>,
#  'so_much': <gensim.models.keyedvectors.Vocab at 0x125a97550>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x125a97588>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x125a975c0>,
#  'garden': <gensim.models.keyedvectors.Vocab at 0x125a975f8>,
#  'the_neighbors': <gensim.models.keyedvectors.Vocab at 0x125a97630>,
#  's': <gensim.models.keyedvectors.Vocab at 0x125a97668>,
#  'a_small': <gensim.models.keyedvectors.Vocab at 0x125a976a0>,
#  'dudley': <gensim.models.keyedvectors.Vocab at 0x125a976d8>,
#  'in_their': <gensim.models.keyedvectors.Vocab at 0x125a97710>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x125a97748>,
#  'there_was': <gensim.models.keyedvectors.Vocab at 0x125a97780>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x125a977b8>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x125a977f0>,
#  'anywhere': <gensim.models.keyedvectors.Vocab at 0x125a97828>,
#  'the_dursleys': <gensim.models.keyedvectors.Vocab at 0x125a97860>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x125a97898>,
#  'they_wanted': <gensim.models.keyedvectors.Vocab at 0x125a978d0>,
#  'but_they': <gensim.models.keyedvectors.Vocab at 0x125a97908>,
#  'also_had': <gensim.models.keyedvectors.Vocab at 0x125a97940>,
#  'a_secret': <gensim.models.keyedvectors.Vocab at 0x125a97978>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x125a979b0>,
#  'that_somebody': <gensim.models.keyedvectors.Vocab at 0x125a979e8>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x125a97a20>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x125a97a58>,
#  'they_didn': <gensim.models.keyedvectors.Vocab at 0x125a97a90>,
#  't_think': <gensim.models.keyedvectors.Vocab at 0x125a97ac8>,
#  'they_could': <gensim.models.keyedvectors.Vocab at 0x125a97b00>,
#  'if_anyone': <gensim.models.keyedvectors.Vocab at 0x125a97b38>,
#  'found_out': <gensim.models.keyedvectors.Vocab at 0x125a97b70>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x125a97ba8>,
#  'the_potters': <gensim.models.keyedvectors.Vocab at 0x125a97be0>,
#  'mrs': <gensim.models.keyedvectors.Vocab at 0x125a97c18>,
#  'potter': <gensim.models.keyedvectors.Vocab at 0x125a97c50>,
#  's_sister': <gensim.models.keyedvectors.Vocab at 0x125a97c88>,
#  'hadn_t': <gensim.models.keyedvectors.Vocab at 0x125a97cc0>,
#  'several_years': <gensim.models.keyedvectors.Vocab at 0x125a97cf8>,
#  'in_fact': <gensim.models.keyedvectors.Vocab at 0x125a97d30>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x125a97d68>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x125a97da0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x125a97dd8>,
#  'her_sister': <gensim.models.keyedvectors.Vocab at 0x125a97e10>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x125a97e48>,
#  'for_nothing': <gensim.models.keyedvectors.Vocab at 0x125a97e80>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x125a97eb8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x125a97ef0>,
#  'it_was': <gensim.models.keyedvectors.Vocab at 0x125a97f28>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x125a97f60>,
#  'shuddered': <gensim.models.keyedvectors.Vocab at 0x125a97f98>,
#  'to_think': <gensim.models.keyedvectors.Vocab at 0x125a97fd0>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x125a93048>,
#  'would_say': <gensim.models.keyedvectors.Vocab at 0x125a93080>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x125a930b8>,
#  'arrived_in': <gensim.models.keyedvectors.Vocab at 0x125a930f0>,
#  'the_street': <gensim.models.keyedvectors.Vocab at 0x125a93128>,
#  'knew_that': <gensim.models.keyedvectors.Vocab at 0x125a93160>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x125a93198>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x125a931d0>,
#  'had_never': <gensim.models.keyedvectors.Vocab at 0x125a93208>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x125a93240>,
#  'this_boy': <gensim.models.keyedvectors.Vocab at 0x125a93278>,
#  'was_another': <gensim.models.keyedvectors.Vocab at 0x125a932b0>,
#  'good_reason': <gensim.models.keyedvectors.Vocab at 0x125a932e8>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x125a93320>,
#  't_want': <gensim.models.keyedvectors.Vocab at 0x125a93358>,
#  'a_child': <gensim.models.keyedvectors.Vocab at 0x125a93390>,
#  'like_that': <gensim.models.keyedvectors.Vocab at 0x125a933c8>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x125a93400>,
#  'woke_up': <gensim.models.keyedvectors.Vocab at 0x125a93438>,
#  'on_the': <gensim.models.keyedvectors.Vocab at 0x125a93470>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x125a934a8>,
#  'gray': <gensim.models.keyedvectors.Vocab at 0x125a934e0>,
#  'tuesday': <gensim.models.keyedvectors.Vocab at 0x125a93518>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x125a93550>,
#  'nothing_about': <gensim.models.keyedvectors.Vocab at 0x125a93588>,
#  'to_suggest': <gensim.models.keyedvectors.Vocab at 0x125a935c0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x125a935f8>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x125a93630>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x125a93668>,
#  'would_soon': <gensim.models.keyedvectors.Vocab at 0x125a936a0>,
#  'all_over': <gensim.models.keyedvectors.Vocab at 0x125a936d8>,
#  'the_country': <gensim.models.keyedvectors.Vocab at 0x125a93710>,
#  'as_he': <gensim.models.keyedvectors.Vocab at 0x125a93748>,
#  'picked': <gensim.models.keyedvectors.Vocab at 0x125a93780>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x125a937b8>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x125a937f0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x125a93828>,
#  'happily_as': <gensim.models.keyedvectors.Vocab at 0x125a93860>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x125a93898>,
#  'screaming': <gensim.models.keyedvectors.Vocab at 0x125a938d0>,
#  'into_his': <gensim.models.keyedvectors.Vocab at 0x125a93908>,
#  'none_of': <gensim.models.keyedvectors.Vocab at 0x125a93940>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x125a93978>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x125a939b0>,
#  'a_large': <gensim.models.keyedvectors.Vocab at 0x125a939e8>,
#  'flutter': <gensim.models.keyedvectors.Vocab at 0x125a93a20>,
#  'past_the': <gensim.models.keyedvectors.Vocab at 0x125a93a58>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x125a93a90>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x125a93ac8>,
#  'half_past': <gensim.models.keyedvectors.Vocab at 0x125a93b00>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x125a93b38>,
#  'picked_up': <gensim.models.keyedvectors.Vocab at 0x125a93b70>,
#  'tried_to': <gensim.models.keyedvectors.Vocab at 0x125a93ba8>,
#  'kiss': <gensim.models.keyedvectors.Vocab at 0x125a93be0>,
#  'good_bye': <gensim.models.keyedvectors.Vocab at 0x125a93c18>,
#  'dudley_was': <gensim.models.keyedvectors.Vocab at 0x125a93c50>,
#  'and_throwing': <gensim.models.keyedvectors.Vocab at 0x125a93c88>,
#  'at_the': <gensim.models.keyedvectors.Vocab at 0x125a93cc0>,
#  'walls': <gensim.models.keyedvectors.Vocab at 0x125a93cf8>,
#  'chortled': <gensim.models.keyedvectors.Vocab at 0x125a93d30>,
#  'left_the': <gensim.models.keyedvectors.Vocab at 0x125a93d68>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x125a93da0>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x125a93dd8>,
#  'got_into': <gensim.models.keyedvectors.Vocab at 0x125a93e10>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x125a93e48>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x125a93e80>,
#  'corner_of': <gensim.models.keyedvectors.Vocab at 0x125a93eb8>,
#  'that_he': <gensim.models.keyedvectors.Vocab at 0x125a93ef0>,
#  'the_first': <gensim.models.keyedvectors.Vocab at 0x125a93f28>,
#  'sign_of': <gensim.models.keyedvectors.Vocab at 0x125a93f60>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x125a93f98>,
#  'peculiar': <gensim.models.keyedvectors.Vocab at 0x125a93fd0>,
#  'a_cat': <gensim.models.keyedvectors.Vocab at 0x125a7f048>,
#  'reading_a': <gensim.models.keyedvectors.Vocab at 0x125a7f0b8>,
#  'map': <gensim.models.keyedvectors.Vocab at 0x125a7f0f0>,
#  'for_a': <gensim.models.keyedvectors.Vocab at 0x125a7f160>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x125a7f198>,
#  'realize_what': <gensim.models.keyedvectors.Vocab at 0x125a7f1d0>,
#  'he_had': <gensim.models.keyedvectors.Vocab at 0x125a7f208>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x125a7f240>,
#  'then_he': <gensim.models.keyedvectors.Vocab at 0x125a7f278>,
#  'jerked_his': <gensim.models.keyedvectors.Vocab at 0x125a7f2e8>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x125a7f320>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x125a7f358>,
#  'to_look': <gensim.models.keyedvectors.Vocab at 0x125a7f128>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x125a7f2b0>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x125a7f400>,
#  'standing_on': <gensim.models.keyedvectors.Vocab at 0x125a7f438>,
#  'the_corner': <gensim.models.keyedvectors.Vocab at 0x125a7f390>,
#  'of_privet': <gensim.models.keyedvectors.Vocab at 0x125a7f4e0>,
#  'but_there': <gensim.models.keyedvectors.Vocab at 0x125a7f3c8>,
#  'wasn_t': <gensim.models.keyedvectors.Vocab at 0x125a7f518>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x125a7f550>,
#  'sight': <gensim.models.keyedvectors.Vocab at 0x125a7f4a8>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x125a7f5c0>,
#  'have_been': <gensim.models.keyedvectors.Vocab at 0x125a7f5f8>,
#  'thinking_of': <gensim.models.keyedvectors.Vocab at 0x125a7f630>,
#  'it_must': <gensim.models.keyedvectors.Vocab at 0x125a7f588>,
#  'a_trick': <gensim.models.keyedvectors.Vocab at 0x125a7f668>,
#  'of_the': <gensim.models.keyedvectors.Vocab at 0x125a7f6d8>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x125a7f710>,
#  'blinked_and': <gensim.models.keyedvectors.Vocab at 0x125a7f748>,
#  'stared_at': <gensim.models.keyedvectors.Vocab at 0x125a7f780>,
#  'the_cat': <gensim.models.keyedvectors.Vocab at 0x125a7f7b8>,
#  'stared_back': <gensim.models.keyedvectors.Vocab at 0x125a7f7f0>,
#  'drove': <gensim.models.keyedvectors.Vocab at 0x125a7f828>,
#  'around_the': <gensim.models.keyedvectors.Vocab at 0x125a7f860>,
#  'corner_and': <gensim.models.keyedvectors.Vocab at 0x125a7f898>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x125a7f8d0>,
#  'the_road': <gensim.models.keyedvectors.Vocab at 0x125a7f908>,
#  'he_watched': <gensim.models.keyedvectors.Vocab at 0x125a7f940>,
#  'in_his': <gensim.models.keyedvectors.Vocab at 0x125a7f6a0>,
#  'mirror': <gensim.models.keyedvectors.Vocab at 0x125a7f9b0>,
#  'sign_that': <gensim.models.keyedvectors.Vocab at 0x125a7f9e8>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x125a7fa20>,
#  'privet_drive': <gensim.models.keyedvectors.Vocab at 0x125a7fa58>,
#  'looking_at': <gensim.models.keyedvectors.Vocab at 0x125a7fa90>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x125a7fb00>,
#  'cats': <gensim.models.keyedvectors.Vocab at 0x125a7f470>,
#  'couldn_t': <gensim.models.keyedvectors.Vocab at 0x125a7f978>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x125a7f080>,
#  'signs': <gensim.models.keyedvectors.Vocab at 0x125a7fba8>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x125a7fbe0>,
#  'himself': <gensim.models.keyedvectors.Vocab at 0x125a7fc18>,
#  'a_little': <gensim.models.keyedvectors.Vocab at 0x125a7fc50>,
#  'shake': <gensim.models.keyedvectors.Vocab at 0x125a7fc88>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x125a7fcc0>,
#  'out_of': <gensim.models.keyedvectors.Vocab at 0x125a7fb70>,
#  'his_mind': <gensim.models.keyedvectors.Vocab at 0x125a7fd30>,
#  'toward': <gensim.models.keyedvectors.Vocab at 0x125a7fd68>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x125a7fda0>,
#  'he_thought': <gensim.models.keyedvectors.Vocab at 0x125a7fdd8>,
#  'nothing_except': <gensim.models.keyedvectors.Vocab at 0x125a7fac8>,
#  'order_of': <gensim.models.keyedvectors.Vocab at 0x125a7fef0>,
#  'hoping_to': <gensim.models.keyedvectors.Vocab at 0x125a7feb8>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x125a7ff28>,
#  'that_day': <gensim.models.keyedvectors.Vocab at 0x125a7ff60>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x125a7ff98>,
#  'edge_of': <gensim.models.keyedvectors.Vocab at 0x125a7ffd0>,
#  'of_his': <gensim.models.keyedvectors.Vocab at 0x125a7fe80>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x125a7fe48>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x125a7fb38>,
#  'something_else': <gensim.models.keyedvectors.Vocab at 0x125a7fe10>,
#  'sat_in': <gensim.models.keyedvectors.Vocab at 0x125a7fcf8>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x125a95048>,
#  'he_couldn': <gensim.models.keyedvectors.Vocab at 0x125a95080>,
#  't_help': <gensim.models.keyedvectors.Vocab at 0x125a950b8>,
#  'noticing_that': <gensim.models.keyedvectors.Vocab at 0x125a950f0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x125a95128>,
#  'seemed_to': <gensim.models.keyedvectors.Vocab at 0x125a95160>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x125a95198>,
#  'a_lot': <gensim.models.keyedvectors.Vocab at 0x125a951d0>,
#  'strangely': <gensim.models.keyedvectors.Vocab at 0x125a95208>,
#  'dressed': <gensim.models.keyedvectors.Vocab at 0x125a95240>,
#  'people_in': <gensim.models.keyedvectors.Vocab at 0x125a95278>,
#  'cloaks': <gensim.models.keyedvectors.Vocab at 0x125a952b0>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x125a952e8>,
#  'people_who': <gensim.models.keyedvectors.Vocab at 0x125a95320>,
#  'dressed_in': <gensim.models.keyedvectors.Vocab at 0x125a95390>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x125a953c8>,
#  'clothes': <gensim.models.keyedvectors.Vocab at 0x125a95400>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x125a954a8>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x125a95470>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x125a954e0>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x125a95518>,
#  'this_was': <gensim.models.keyedvectors.Vocab at 0x125a95550>,
#  'some_stupid': <gensim.models.keyedvectors.Vocab at 0x125a95588>,
#  'his_fingers': <gensim.models.keyedvectors.Vocab at 0x125a955c0>,
#  'steering_wheel': <gensim.models.keyedvectors.Vocab at 0x125a955f8>,
#  'his_eyes': <gensim.models.keyedvectors.Vocab at 0x125a95358>,
#  'fell_on': <gensim.models.keyedvectors.Vocab at 0x125a95630>,
#  'a_huddle': <gensim.models.keyedvectors.Vocab at 0x125a95668>,
#  'of_these': <gensim.models.keyedvectors.Vocab at 0x125a956a0>,
#  'weirdos': <gensim.models.keyedvectors.Vocab at 0x125a956d8>,
#  'standing_quite': <gensim.models.keyedvectors.Vocab at 0x125a95710>,
#  'close_by': <gensim.models.keyedvectors.Vocab at 0x125a95748>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x125a95780>,
#  'to_see': <gensim.models.keyedvectors.Vocab at 0x125a957f0>,
#  'a_couple': <gensim.models.keyedvectors.Vocab at 0x125a95438>,
#  'of_them': <gensim.models.keyedvectors.Vocab at 0x125a95828>,
#  'weren_t': <gensim.models.keyedvectors.Vocab at 0x125a95860>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x125a95898>,
#  'at_all': <gensim.models.keyedvectors.Vocab at 0x125a958d0>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x125a95940>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x125a95978>,
#  'older_than': <gensim.models.keyedvectors.Vocab at 0x125a959b0>,
#  'wearing_an': <gensim.models.keyedvectors.Vocab at 0x125a959e8>,
#  'emerald_green': <gensim.models.keyedvectors.Vocab at 0x125a95a20>,
#  'cloak': <gensim.models.keyedvectors.Vocab at 0x125a95a58>,
#  'nerve': <gensim.models.keyedvectors.Vocab at 0x125a95a90>,
#  'but_then': <gensim.models.keyedvectors.Vocab at 0x125a95ac8>,
#  'it_struck': <gensim.models.keyedvectors.Vocab at 0x125a95b00>,
#  'silly': <gensim.models.keyedvectors.Vocab at 0x125a95b38>,
#  'these_people': <gensim.models.keyedvectors.Vocab at 0x125a95b70>,
#  'collecting': <gensim.models.keyedvectors.Vocab at 0x125a95ba8>,
#  'for_something': <gensim.models.keyedvectors.Vocab at 0x125a95be0>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x125a95c18>,
#  'would_be': <gensim.models.keyedvectors.Vocab at 0x125a95c50>,
#  'moved_on': <gensim.models.keyedvectors.Vocab at 0x125a957b8>,
#  'a_few': <gensim.models.keyedvectors.Vocab at 0x125a95c88>,
#  'minutes_later': <gensim.models.keyedvectors.Vocab at 0x125a95cc0>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x125a95cf8>,
#  'back_on': <gensim.models.keyedvectors.Vocab at 0x125a95d30>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x125a95d68>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x125a95da0>,
#  'with_his': <gensim.models.keyedvectors.Vocab at 0x125a95dd8>,
#  'back_to': <gensim.models.keyedvectors.Vocab at 0x125a95e10>,
#  'the_window': <gensim.models.keyedvectors.Vocab at 0x125a95e48>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x125a95e80>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x125a95908>,
#  'if_he': <gensim.models.keyedvectors.Vocab at 0x125a95ef0>,
#  'he_might': <gensim.models.keyedvectors.Vocab at 0x125a95f28>,
#  'have_found': <gensim.models.keyedvectors.Vocab at 0x125a95f60>,
#  'harder_to': <gensim.models.keyedvectors.Vocab at 0x125a95f98>,
#  'concentrate_on': <gensim.models.keyedvectors.Vocab at 0x125a95fd0>,
#  'he_didn': <gensim.models.keyedvectors.Vocab at 0x125a95eb8>,
#  't_see': <gensim.models.keyedvectors.Vocab at 0x125a78048>,
#  'the_owls': <gensim.models.keyedvectors.Vocab at 0x125a78080>,
#  'swooping': <gensim.models.keyedvectors.Vocab at 0x125a780b8>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x125a780f0>,
#  'daylight': <gensim.models.keyedvectors.Vocab at 0x125a78128>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x125a78160>,
#  'down_in': <gensim.models.keyedvectors.Vocab at 0x125a78198>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x125a78208>,
#  'pointed': <gensim.models.keyedvectors.Vocab at 0x125a78240>,
#  'and_gazed': <gensim.models.keyedvectors.Vocab at 0x125a78278>,
#  'open_mouthed': <gensim.models.keyedvectors.Vocab at 0x125a782b0>,
#  'owl': <gensim.models.keyedvectors.Vocab at 0x125a782e8>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x125a78320>,
#  'sped': <gensim.models.keyedvectors.Vocab at 0x125a78358>,
#  'overhead': <gensim.models.keyedvectors.Vocab at 0x125a78390>,
#  'most_of': <gensim.models.keyedvectors.Vocab at 0x125a783c8>,
#  'an_owl': <gensim.models.keyedvectors.Vocab at 0x125a78400>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x125a78438>,
#  'nighttime': <gensim.models.keyedvectors.Vocab at 0x125a78470>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x125a784a8>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x125a784e0>,
#  'he_yelled': <gensim.models.keyedvectors.Vocab at 0x125a78518>,
#  'at_five': <gensim.models.keyedvectors.Vocab at 0x125a78550>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x125a78588>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x125a785c0>,
#  'shouted': <gensim.models.keyedvectors.Vocab at 0x125a785f8>,
#  'a_bit': <gensim.models.keyedvectors.Vocab at 0x125a78630>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x125a78668>,
#  'in_a': <gensim.models.keyedvectors.Vocab at 0x125a786a0>,
#  'very_good': <gensim.models.keyedvectors.Vocab at 0x125a786d8>,
#  'mood': <gensim.models.keyedvectors.Vocab at 0x125a78710>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x125a781d0>,
#  'lunchtime': <gensim.models.keyedvectors.Vocab at 0x125a78780>,
#  'when_he': <gensim.models.keyedvectors.Vocab at 0x125a787b8>,
#  'thought_he': <gensim.models.keyedvectors.Vocab at 0x125a787f0>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x125a78828>,
#  'his_legs': <gensim.models.keyedvectors.Vocab at 0x125a78860>,
#  'to_buy': <gensim.models.keyedvectors.Vocab at 0x125a78898>,
#  'from_the': <gensim.models.keyedvectors.Vocab at 0x125a788d0>,
#  'he_d': <gensim.models.keyedvectors.Vocab at 0x125a78908>,
#  'until_he': <gensim.models.keyedvectors.Vocab at 0x125a78940>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x125a78978>,
#  'a_group': <gensim.models.keyedvectors.Vocab at 0x125a789b0>,
#  'next_to': <gensim.models.keyedvectors.Vocab at 0x125a789e8>,
#  'eyed': <gensim.models.keyedvectors.Vocab at 0x125a78a20>,
#  'angrily_as': <gensim.models.keyedvectors.Vocab at 0x125a78a58>,
#  'he_passed': <gensim.models.keyedvectors.Vocab at 0x125a78a90>,
#  't_know': <gensim.models.keyedvectors.Vocab at 0x125a78ac8>,
#  'made_him': <gensim.models.keyedvectors.Vocab at 0x125a78b00>,
#  'uneasy': <gensim.models.keyedvectors.Vocab at 0x125a78b38>,
#  'excitedly': <gensim.models.keyedvectors.Vocab at 0x125a78b70>,
#  'a_single': <gensim.models.keyedvectors.Vocab at 0x125a78ba8>,
#  'on_his': <gensim.models.keyedvectors.Vocab at 0x125a78be0>,
#  'way_back': <gensim.models.keyedvectors.Vocab at 0x125a78c18>,
#  'past_them': <gensim.models.keyedvectors.Vocab at 0x125a78c50>,
#  'clutching_a': <gensim.models.keyedvectors.Vocab at 0x125a78c88>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x125a78d30>,
#  'caught': <gensim.models.keyedvectors.Vocab at 0x125a78cf8>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x125a78d68>,
#  'what_they': <gensim.models.keyedvectors.Vocab at 0x125a78da0>,
#  'were_saying': <gensim.models.keyedvectors.Vocab at 0x125a78dd8>,
#  'that_s': <gensim.models.keyedvectors.Vocab at 0x125a78e10>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x125a78e48>,
#  'i_heard': <gensim.models.keyedvectors.Vocab at 0x125a78e80>,
#  'their_son': <gensim.models.keyedvectors.Vocab at 0x125a78eb8>,
#  'harry': <gensim.models.keyedvectors.Vocab at 0x125a78748>,
#  'stopped_dead': <gensim.models.keyedvectors.Vocab at 0x125a78ef0>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x125a78f28>,
#  'flooded': <gensim.models.keyedvectors.Vocab at 0x125a78cc0>,
#  'he_looked': <gensim.models.keyedvectors.Vocab at 0x125a78f98>,
#  'back_at': <gensim.models.keyedvectors.Vocab at 0x125a78fd0>,
#  'as_if': <gensim.models.keyedvectors.Vocab at 0x125a78f60>,
#  'he_wanted': <gensim.models.keyedvectors.Vocab at 0x125a82080>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x125a82128>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x125a820f0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x125a82198>,
#  'he_dashed': <gensim.models.keyedvectors.Vocab at 0x125a821d0>,
#  'back_across': <gensim.models.keyedvectors.Vocab at 0x125a82160>,
#  'hurried_up': <gensim.models.keyedvectors.Vocab at 0x125a822b0>,
#  'his_office': <gensim.models.keyedvectors.Vocab at 0x125a82320>,
#  'snapped_at': <gensim.models.keyedvectors.Vocab at 0x125a82048>,
#  'secretary': <gensim.models.keyedvectors.Vocab at 0x125a82358>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x125a82390>,
#  'to_disturb': <gensim.models.keyedvectors.Vocab at 0x125a823c8>,
#  'seized_his': <gensim.models.keyedvectors.Vocab at 0x125a82470>,
#  'telephone': <gensim.models.keyedvectors.Vocab at 0x125a822e8>,
#  'had_almost': <gensim.models.keyedvectors.Vocab at 0x125a824a8>,
#  'finished': <gensim.models.keyedvectors.Vocab at 0x125a824e0>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x125a82518>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x125a82550>,
#  'he_put': <gensim.models.keyedvectors.Vocab at 0x125a82588>,
#  'the_receiver': <gensim.models.keyedvectors.Vocab at 0x125a825c0>,
#  'back_down': <gensim.models.keyedvectors.Vocab at 0x125a825f8>,
#  'his_mustache': <gensim.models.keyedvectors.Vocab at 0x125a82630>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x125a826a0>,
#  'being_stupid': <gensim.models.keyedvectors.Vocab at 0x125a82438>,
#  'such_an': <gensim.models.keyedvectors.Vocab at 0x125a826d8>,
#  'unusual': <gensim.models.keyedvectors.Vocab at 0x125a82710>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x125a82748>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x125a82780>,
#  'there_were': <gensim.models.keyedvectors.Vocab at 0x125a827b8>,
#  'lots_of': <gensim.models.keyedvectors.Vocab at 0x125a827f0>,
#  'who_had': <gensim.models.keyedvectors.Vocab at 0x125a82668>,
#  'come_to': <gensim.models.keyedvectors.Vocab at 0x125a82860>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x125a82898>,
#  'he_wasn': <gensim.models.keyedvectors.Vocab at 0x125a828d0>,
#  't_even': <gensim.models.keyedvectors.Vocab at 0x125a82908>,
#  'never_even': <gensim.models.keyedvectors.Vocab at 0x125a829b0>,
#  'it_might': <gensim.models.keyedvectors.Vocab at 0x125a82208>,
#  'no_point': <gensim.models.keyedvectors.Vocab at 0x125a829e8>,
#  'worrying': <gensim.models.keyedvectors.Vocab at 0x125a82a20>,
#  'she_always': <gensim.models.keyedvectors.Vocab at 0x125a82a58>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x125a82ac8>,
#  'at_any': <gensim.models.keyedvectors.Vocab at 0x125a82400>,
#  'mention_of': <gensim.models.keyedvectors.Vocab at 0x125a82a90>,
#  't_blame': <gensim.models.keyedvectors.Vocab at 0x125a82b38>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x125a82940>,
#  'the_same': <gensim.models.keyedvectors.Vocab at 0x125a82ba8>,
#  'those_people': <gensim.models.keyedvectors.Vocab at 0x125a82b00>,
#  'he_found': <gensim.models.keyedvectors.Vocab at 0x125a82278>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x125a82978>,
#  'building': <gensim.models.keyedvectors.Vocab at 0x125a82828>,
#  'o_clock': <gensim.models.keyedvectors.Vocab at 0x125a82cc0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x125a82c88>,
#  'so_worried': <gensim.models.keyedvectors.Vocab at 0x125a82cf8>,
#  'walked_straight': <gensim.models.keyedvectors.Vocab at 0x125a82d30>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x125a82d68>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x125a82be0>,
#  'just_outside': <gensim.models.keyedvectors.Vocab at 0x125a82c18>,
#  'the_door': <gensim.models.keyedvectors.Vocab at 0x125a82c50>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x125a82e10>,
#  'he_grunted': <gensim.models.keyedvectors.Vocab at 0x125a82e80>,
#  'the_tiny': <gensim.models.keyedvectors.Vocab at 0x125a820b8>,
#  'old_man': <gensim.models.keyedvectors.Vocab at 0x125a82eb8>,
#  'stumbled_and': <gensim.models.keyedvectors.Vocab at 0x125a82ef0>,
#  'almost_fell': <gensim.models.keyedvectors.Vocab at 0x125a82b70>,
#  'seconds_before': <gensim.models.keyedvectors.Vocab at 0x125a82f98>,
#  'realized_that': <gensim.models.keyedvectors.Vocab at 0x125a82fd0>,
#  'the_man': <gensim.models.keyedvectors.Vocab at 0x125a82f60>,
#  'was_wearing': <gensim.models.keyedvectors.Vocab at 0x125a82dd8>,
#  'violet': <gensim.models.keyedvectors.Vocab at 0x125a82da0>,
#  't_seem': <gensim.models.keyedvectors.Vocab at 0x125a82240>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x125a82f28>,
#  'the_ground': <gensim.models.keyedvectors.Vocab at 0x125a82e48>,
#  'into_a': <gensim.models.keyedvectors.Vocab at 0x125a8ce80>,
#  'he_said': <gensim.models.keyedvectors.Vocab at 0x125a8c048>,
#  'that_made': <gensim.models.keyedvectors.Vocab at 0x125a8c080>,
#  'passersby': <gensim.models.keyedvectors.Vocab at 0x125a8c0b8>,
#  'stare': <gensim.models.keyedvectors.Vocab at 0x125a8c0f0>,
#  'don_t': <gensim.models.keyedvectors.Vocab at 0x125a8c128>,
#  'my_dear': <gensim.models.keyedvectors.Vocab at 0x125a8c198>,
#  'sir': <gensim.models.keyedvectors.Vocab at 0x125a8c208>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x125a8c240>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x125a8c278>,
#  'you_know': <gensim.models.keyedvectors.Vocab at 0x125a8c2e8>,
#  'who_has': <gensim.models.keyedvectors.Vocab at 0x125a8c320>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x125a8c358>,
#  'at_last': <gensim.models.keyedvectors.Vocab at 0x125a8c1d0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x125a8c3c8>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x125a8c400>,
#  'should_be': <gensim.models.keyedvectors.Vocab at 0x125a8c438>,
#  'celebrating': <gensim.models.keyedvectors.Vocab at 0x125a8c390>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x125a8c470>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x125a8c4e0>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x125a8c518>,
#  'the_old': <gensim.models.keyedvectors.Vocab at 0x125a8c4a8>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x125a8c5c0>,
#  'and_walked': <gensim.models.keyedvectors.Vocab at 0x125a8c5f8>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x125a8c630>,
#  'the_spot': <gensim.models.keyedvectors.Vocab at 0x125a8c668>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x125a8c6a0>,
#  'by_a': <gensim.models.keyedvectors.Vocab at 0x125a8c6d8>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x125a8c550>,
#  'stranger': <gensim.models.keyedvectors.Vocab at 0x125a8c588>,
#  'he_also': <gensim.models.keyedvectors.Vocab at 0x125a8c160>,
#  'had_been': <gensim.models.keyedvectors.Vocab at 0x125a8c7f0>,
#  'a_muggle': <gensim.models.keyedvectors.Vocab at 0x125a8c828>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x125a8c710>,
#  'rattled': <gensim.models.keyedvectors.Vocab at 0x125a8c898>,
#  'he_hurried': <gensim.models.keyedvectors.Vocab at 0x125a8c8d0>,
#  'and_set': <gensim.models.keyedvectors.Vocab at 0x125a8c908>,
#  'off_for': <gensim.models.keyedvectors.Vocab at 0x125a8c940>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x125a8c780>,
#  'which_he': <gensim.models.keyedvectors.Vocab at 0x125a8c860>,
#  'hoped': <gensim.models.keyedvectors.Vocab at 0x125a8c7b8>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x125a8ca20>,
#  'because_he': <gensim.models.keyedvectors.Vocab at 0x125a8c2b0>,
#  'imagination': <gensim.models.keyedvectors.Vocab at 0x125a8cb00>,
#  'pulled': <gensim.models.keyedvectors.Vocab at 0x125a8c748>,
#  'into_the': <gensim.models.keyedvectors.Vocab at 0x125a8c978>,
#  'thing_he': <gensim.models.keyedvectors.Vocab at 0x125a8cb70>,
#  'spotted': <gensim.models.keyedvectors.Vocab at 0x125a8cba8>,
#  'that_morning': <gensim.models.keyedvectors.Vocab at 0x125a8c9b0>,
#  'now_sitting': <gensim.models.keyedvectors.Vocab at 0x125a8cc50>,
#  'sure_it': <gensim.models.keyedvectors.Vocab at 0x125a8cb38>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x125a8cc88>,
#  'markings_around': <gensim.models.keyedvectors.Vocab at 0x125a8ccc0>,
#  'its_eyes': <gensim.models.keyedvectors.Vocab at 0x125a8cd30>,
#  'said_mr': <gensim.models.keyedvectors.Vocab at 0x125a8cd68>,
#  'loudly': <gensim.models.keyedvectors.Vocab at 0x125a8cc18>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x125a8cda0>,
#  'gave_him': <gensim.models.keyedvectors.Vocab at 0x125a8cac8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x125a8cdd8>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x125a8ce10>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x125a8ce48>,
#  'wondered': <gensim.models.keyedvectors.Vocab at 0x125a8cf28>,
#  'trying_to': <gensim.models.keyedvectors.Vocab at 0x125a8ca58>,
#  'pull_himself': <gensim.models.keyedvectors.Vocab at 0x125a8cef0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x125a8cf60>,
#  'himself_into': <gensim.models.keyedvectors.Vocab at 0x125a8cf98>,
#  'the_house': <gensim.models.keyedvectors.Vocab at 0x125a8cfd0>,
#  'to_mention': <gensim.models.keyedvectors.Vocab at 0x125a8ccf8>,
#  'anything_to': <gensim.models.keyedvectors.Vocab at 0x125a8ca90>,
#  'his_wife': <gensim.models.keyedvectors.Vocab at 0x125a8c9e8>,
#  'a_nice': <gensim.models.keyedvectors.Vocab at 0x125a8cbe0>,
#  'she_told': <gensim.models.keyedvectors.Vocab at 0x125a8ceb8>,
#  'all_about': <gensim.models.keyedvectors.Vocab at 0x125a84eb8>,
#  'next_door': <gensim.models.keyedvectors.Vocab at 0x125a840b8>,
#  'her_daughter': <gensim.models.keyedvectors.Vocab at 0x125a84048>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x125a840f0>,
#  'dudley_had': <gensim.models.keyedvectors.Vocab at 0x125a841d0>,
#  'learned': <gensim.models.keyedvectors.Vocab at 0x125a84198>,
#  'a_new': <gensim.models.keyedvectors.Vocab at 0x125a84240>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x125a84160>,
#  'won_t': <gensim.models.keyedvectors.Vocab at 0x125a842b0>,
#  'been_put': <gensim.models.keyedvectors.Vocab at 0x125a842e8>,
#  'to_bed': <gensim.models.keyedvectors.Vocab at 0x125a84320>,
#  'he_went': <gensim.models.keyedvectors.Vocab at 0x125a84358>,
#  'living_room': <gensim.models.keyedvectors.Vocab at 0x125a84390>,
#  'in_time': <gensim.models.keyedvectors.Vocab at 0x125a84080>,
#  'to_catch': <gensim.models.keyedvectors.Vocab at 0x125a84438>,
#  'evening': <gensim.models.keyedvectors.Vocab at 0x125a84208>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x125a844a8>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x125a84400>,
#  'bird': <gensim.models.keyedvectors.Vocab at 0x125a844e0>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x125a84518>,
#  'unusually': <gensim.models.keyedvectors.Vocab at 0x125a84550>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x125a84588>,
#  'owls': <gensim.models.keyedvectors.Vocab at 0x125a845c0>,
#  'normally': <gensim.models.keyedvectors.Vocab at 0x125a845f8>,
#  'hunt': <gensim.models.keyedvectors.Vocab at 0x125a84668>,
#  'at_night': <gensim.models.keyedvectors.Vocab at 0x125a84470>,
#  'ever_seen': <gensim.models.keyedvectors.Vocab at 0x125a846a0>,
#  'hundreds_of': <gensim.models.keyedvectors.Vocab at 0x125a846d8>,
#  'flying_in': <gensim.models.keyedvectors.Vocab at 0x125a843c8>,
#  'every_direction': <gensim.models.keyedvectors.Vocab at 0x125a84748>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x125a84780>,
#  'sunrise': <gensim.models.keyedvectors.Vocab at 0x125a84828>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x125a84128>,
#  'unable_to': <gensim.models.keyedvectors.Vocab at 0x125a84630>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x125a84860>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x125a84940>,
#  'allowed_himself': <gensim.models.keyedvectors.Vocab at 0x125a84978>,
#  'a_grin': <gensim.models.keyedvectors.Vocab at 0x125a84710>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x125a84278>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x125a84a58>,
#  'the_weather': <gensim.models.keyedvectors.Vocab at 0x125a847f0>,
#  'going_to': <gensim.models.keyedvectors.Vocab at 0x125a84ac8>,
#  'be_any': <gensim.models.keyedvectors.Vocab at 0x125a84b00>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x125a848d0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x125a84b70>,
#  'ted': <gensim.models.keyedvectors.Vocab at 0x125a84ba8>,
#  'i_don': <gensim.models.keyedvectors.Vocab at 0x125a84be0>,
#  'but_it': <gensim.models.keyedvectors.Vocab at 0x125a84c18>,
#  's_not': <gensim.models.keyedvectors.Vocab at 0x125a84c50>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x125a84c88>,
#  'as_far': <gensim.models.keyedvectors.Vocab at 0x125a84cc0>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x125a84cf8>,
#  'to_tell': <gensim.models.keyedvectors.Vocab at 0x125a849b0>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x125a84a90>,
#  'instead_of': <gensim.models.keyedvectors.Vocab at 0x125a84a20>,
#  'the_rain': <gensim.models.keyedvectors.Vocab at 0x125a849e8>,
#  'i_promised': <gensim.models.keyedvectors.Vocab at 0x125a84da0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x125a84d68>,
#  'they_ve': <gensim.models.keyedvectors.Vocab at 0x125a84dd8>,
#  'shooting_stars': <gensim.models.keyedvectors.Vocab at 0x125a84e10>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x125a84e48>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x125a84d30>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x125a847b8>,
#  'it_s': <gensim.models.keyedvectors.Vocab at 0x125a84f28>,
#  'not_until': <gensim.models.keyedvectors.Vocab at 0x125a84f60>,
#  'next_week': <gensim.models.keyedvectors.Vocab at 0x125a84fd0>,
#  'but_i': <gensim.models.keyedvectors.Vocab at 0x125a84e80>,
#  'armchair': <gensim.models.keyedvectors.Vocab at 0x125a84f98>,
#  'britain': <gensim.models.keyedvectors.Vocab at 0x125a84b38>,
#  'flying': <gensim.models.keyedvectors.Vocab at 0x125a84908>,
#  'the_place': <gensim.models.keyedvectors.Vocab at 0x125a84ef0>,
#  'a_whisper': <gensim.models.keyedvectors.Vocab at 0x125a84898>,
#  'came_into': <gensim.models.keyedvectors.Vocab at 0x125aad278>,
#  'the_living': <gensim.models.keyedvectors.Vocab at 0x125aad2e8>,
#  'of_tea': <gensim.models.keyedvectors.Vocab at 0x125aad358>,
#  'no_good': <gensim.models.keyedvectors.Vocab at 0x125aad390>,
#  'have_to': <gensim.models.keyedvectors.Vocab at 0x125aad3c8>,
#  'say_something': <gensim.models.keyedvectors.Vocab at 0x125aad2b0>,
#  'he_cleared': <gensim.models.keyedvectors.Vocab at 0x125aad4a8>,
#  'his_throat': <gensim.models.keyedvectors.Vocab at 0x125aad4e0>,
#  'nervously': <gensim.models.keyedvectors.Vocab at 0x125aad518>,
#  'er': <gensim.models.keyedvectors.Vocab at 0x125aad550>,
#  'you_haven': <gensim.models.keyedvectors.Vocab at 0x125aad588>,
#  't': <gensim.models.keyedvectors.Vocab at 0x125aad5f8>,
#  'heard_from': <gensim.models.keyedvectors.Vocab at 0x125aad6a0>,
#  'your_sister': <gensim.models.keyedvectors.Vocab at 0x125aad6d8>,
#  'lately': <gensim.models.keyedvectors.Vocab at 0x125aad5c0>,
#  'have_you': <gensim.models.keyedvectors.Vocab at 0x125aad748>,
#  'had_expected': <gensim.models.keyedvectors.Vocab at 0x125aad438>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x125aad470>,
#  'after_all': <gensim.models.keyedvectors.Vocab at 0x125aad710>,
#  'she_said': <gensim.models.keyedvectors.Vocab at 0x125aad320>,
#  'sharply': <gensim.models.keyedvectors.Vocab at 0x125aad7f0>,
#  'mumbled': <gensim.models.keyedvectors.Vocab at 0x125aad668>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x125aad400>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x125aad240>,
#  'snapped_mrs': <gensim.models.keyedvectors.Vocab at 0x125aad8d0>,
#  'well_i': <gensim.models.keyedvectors.Vocab at 0x125aad978>,
#  'just_thought': <gensim.models.keyedvectors.Vocab at 0x125aad630>,
#  'maybe_it': <gensim.models.keyedvectors.Vocab at 0x125aad898>,
#  'to_do': <gensim.models.keyedvectors.Vocab at 0x125aada20>,
#  'crowd': <gensim.models.keyedvectors.Vocab at 0x125aada90>,
#  'her_tea': <gensim.models.keyedvectors.Vocab at 0x125aad9b0>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x125aad828>,
#  'lips': <gensim.models.keyedvectors.Vocab at 0x125aadac8>,
#  'wondered_whether': <gensim.models.keyedvectors.Vocab at 0x125aadb70>,
#  'tell_her': <gensim.models.keyedvectors.Vocab at 0x125aad860>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x125aadba8>,
#  'the_name': <gensim.models.keyedvectors.Vocab at 0x125aadc88>,
#  'decided': <gensim.models.keyedvectors.Vocab at 0x125aadc50>,
#  't_dare': <gensim.models.keyedvectors.Vocab at 0x125aadcc0>,
#  'instead_he': <gensim.models.keyedvectors.Vocab at 0x125aada58>,
#  'dudley_s': <gensim.models.keyedvectors.Vocab at 0x125aad940>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x125aad908>,
#  'wouldn_t': <gensim.models.keyedvectors.Vocab at 0x125aadd68>,
#  'i_suppose': <gensim.models.keyedvectors.Vocab at 0x125aade80>,
#  'said_mrs': <gensim.models.keyedvectors.Vocab at 0x125aadd30>,
#  'stiffly': <gensim.models.keyedvectors.Vocab at 0x125aadb38>,
#  'what_s': <gensim.models.keyedvectors.Vocab at 0x125aad9e8>,
#  'his_name': <gensim.models.keyedvectors.Vocab at 0x125aadeb8>,
#  'isn_t': <gensim.models.keyedvectors.Vocab at 0x125aadef0>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x125aadda0>,
#  'if_you': <gensim.models.keyedvectors.Vocab at 0x125aadf60>,
#  'ask_me': <gensim.models.keyedvectors.Vocab at 0x125aadf28>,
#  'oh_yes': <gensim.models.keyedvectors.Vocab at 0x125aadfd0>,
#  'his_heart': <gensim.models.keyedvectors.Vocab at 0x125aadf98>,
#  'sinking': <gensim.models.keyedvectors.Vocab at 0x125aadc18>,
#  'horribly': <gensim.models.keyedvectors.Vocab at 0x125aadb00>,
#  'yes_i': <gensim.models.keyedvectors.Vocab at 0x125aade10>,
#  't_say': <gensim.models.keyedvectors.Vocab at 0x125aad7b8>,
#  'another_word': <gensim.models.keyedvectors.Vocab at 0x125aade48>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x125aadbe0>,
#  'as_they': <gensim.models.keyedvectors.Vocab at 0x125aad780>,
#  'while_mrs': <gensim.models.keyedvectors.Vocab at 0x125aaddd8>,
#  'in_the': <gensim.models.keyedvectors.Vocab at 0x125aadcf8>,
#  'bathroom': <gensim.models.keyedvectors.Vocab at 0x125aad048>,
#  'crept': <gensim.models.keyedvectors.Vocab at 0x125aad080>,
#  'the_bedroom': <gensim.models.keyedvectors.Vocab at 0x125aad0f0>,
#  'window_and': <gensim.models.keyedvectors.Vocab at 0x125aad128>,
#  'was_still': <gensim.models.keyedvectors.Vocab at 0x125aad198>,
#  'staring_down': <gensim.models.keyedvectors.Vocab at 0x125aad1d0>,
#  'as_though': <gensim.models.keyedvectors.Vocab at 0x125aad208>,
#  'were_waiting': <gensim.models.keyedvectors.Vocab at 0x125aad160>,
#  'all_this': <gensim.models.keyedvectors.Vocab at 0x125aad0b8>,
#  'do_with': <gensim.models.keyedvectors.Vocab at 0x125a81ef0>,
#  'if_it': <gensim.models.keyedvectors.Vocab at 0x125a81080>,
#  'related_to': <gensim.models.keyedvectors.Vocab at 0x125a810f0>,
#  'a_pair': <gensim.models.keyedvectors.Vocab at 0x125a81048>,
#  'he_could': <gensim.models.keyedvectors.Vocab at 0x125a81198>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x125a81208>,
#  'fell_asleep': <gensim.models.keyedvectors.Vocab at 0x125a81240>,
#  'quickly': <gensim.models.keyedvectors.Vocab at 0x125a813c8>,
#  'lay_awake': <gensim.models.keyedvectors.Vocab at 0x125a81160>,
#  'turning': <gensim.models.keyedvectors.Vocab at 0x125a81128>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x125a81400>,
#  'comforting': <gensim.models.keyedvectors.Vocab at 0x125a814a8>,
#  'before_he': <gensim.models.keyedvectors.Vocab at 0x125a810b8>,
#  'even_if': <gensim.models.keyedvectors.Vocab at 0x125a814e0>,
#  'no_reason': <gensim.models.keyedvectors.Vocab at 0x125a81518>,
#  'to_come': <gensim.models.keyedvectors.Vocab at 0x125a81390>,
#  'near_him': <gensim.models.keyedvectors.Vocab at 0x125a81550>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x125a81588>,
#  'very_well': <gensim.models.keyedvectors.Vocab at 0x125a815c0>,
#  'what_he': <gensim.models.keyedvectors.Vocab at 0x125a812b0>,
#  'petunia': <gensim.models.keyedvectors.Vocab at 0x125a81320>,
#  'thought_about': <gensim.models.keyedvectors.Vocab at 0x125a81278>,
#  'could_get': <gensim.models.keyedvectors.Vocab at 0x125a816d8>,
#  'mixed_up': <gensim.models.keyedvectors.Vocab at 0x125a81470>,
#  'anything_that': <gensim.models.keyedvectors.Vocab at 0x125a81710>,
#  'might_be': <gensim.models.keyedvectors.Vocab at 0x125a81780>,
#  'going_on': <gensim.models.keyedvectors.Vocab at 0x125a815f8>,
#  'and_turned': <gensim.models.keyedvectors.Vocab at 0x125a817b8>,
#  'how_very': <gensim.models.keyedvectors.Vocab at 0x125a816a0>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x125a81630>,
#  'might_have': <gensim.models.keyedvectors.Vocab at 0x125a812e8>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x125a818d0>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x125a81748>,
#  'was_showing': <gensim.models.keyedvectors.Vocab at 0x125a81828>,
#  'no_sign': <gensim.models.keyedvectors.Vocab at 0x125a81668>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x125a819e8>,
#  'a_statue': <gensim.models.keyedvectors.Vocab at 0x125a817f0>,
#  'far_corner': <gensim.models.keyedvectors.Vocab at 0x125a81358>,
#  'quiver': <gensim.models.keyedvectors.Vocab at 0x125a81a58>,
#  'a_car': <gensim.models.keyedvectors.Vocab at 0x125a81a90>,
#  'door_slammed': <gensim.models.keyedvectors.Vocab at 0x125a81ac8>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x125a81b00>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x125a81b38>,
#  'nor': <gensim.models.keyedvectors.Vocab at 0x125a811d0>,
#  'swooped': <gensim.models.keyedvectors.Vocab at 0x125a81908>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x125a81a20>,
#  'a_man': <gensim.models.keyedvectors.Vocab at 0x125a81be0>,
#  'appeared_on': <gensim.models.keyedvectors.Vocab at 0x125a81c50>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x125a81898>,
#  'appeared': <gensim.models.keyedvectors.Vocab at 0x125a819b0>,
#  'so_suddenly': <gensim.models.keyedvectors.Vocab at 0x125a81978>,
#  'silently': <gensim.models.keyedvectors.Vocab at 0x125a81c88>,
#  'have_thought': <gensim.models.keyedvectors.Vocab at 0x125a81860>,
#  's_tail': <gensim.models.keyedvectors.Vocab at 0x125a81d30>,
#  'narrowed': <gensim.models.keyedvectors.Vocab at 0x125a81b70>,
#  'nothing_like': <gensim.models.keyedvectors.Vocab at 0x125a81ba8>,
#  'this_man': <gensim.models.keyedvectors.Vocab at 0x125a81dd8>,
#  'had_ever': <gensim.models.keyedvectors.Vocab at 0x125a81cc0>,
#  'been_seen': <gensim.models.keyedvectors.Vocab at 0x125a81940>,
#  'on_privet': <gensim.models.keyedvectors.Vocab at 0x125a81e48>,
#  'tall_thin': <gensim.models.keyedvectors.Vocab at 0x125a81e80>,
#  'very_old': <gensim.models.keyedvectors.Vocab at 0x125a81eb8>,
#  'judging_by': <gensim.models.keyedvectors.Vocab at 0x125a81f28>,
#  'the_silver': <gensim.models.keyedvectors.Vocab at 0x125a81d68>,
#  'hair_and': <gensim.models.keyedvectors.Vocab at 0x125a81fd0>,
#  'beard': <gensim.models.keyedvectors.Vocab at 0x125a81da0>,
#  'which_were': <gensim.models.keyedvectors.Vocab at 0x125a81e10>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x125a81c18>,
#  'long_enough': <gensim.models.keyedvectors.Vocab at 0x125a81cf8>,
#  'belt': <gensim.models.keyedvectors.Vocab at 0x125a81f60>,
#  'wearing_long': <gensim.models.keyedvectors.Vocab at 0x125a81f98>,
#  'robes': <gensim.models.keyedvectors.Vocab at 0x125a81438>,
#  'purple': <gensim.models.keyedvectors.Vocab at 0x125aa1048>,
#  'swept': <gensim.models.keyedvectors.Vocab at 0x125aa10f0>,
#  'buckled': <gensim.models.keyedvectors.Vocab at 0x125aa1128>,
#  'boots': <gensim.models.keyedvectors.Vocab at 0x125aa1160>,
#  'blue_eyes': <gensim.models.keyedvectors.Vocab at 0x125aa1198>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x125aa10b8>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x125aa1080>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x125aa1240>,
#  'half_moon': <gensim.models.keyedvectors.Vocab at 0x125aa1208>,
#  'spectacles_and': <gensim.models.keyedvectors.Vocab at 0x125aa12b0>,
#  'his_nose': <gensim.models.keyedvectors.Vocab at 0x125aa1358>,
#  'was_very': <gensim.models.keyedvectors.Vocab at 0x125aa11d0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x125aa1278>,
#  'crooked': <gensim.models.keyedvectors.Vocab at 0x125aa1390>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x125aa1320>,
#  'at_least': <gensim.models.keyedvectors.Vocab at 0x125aa1400>,
#  's_name': <gensim.models.keyedvectors.Vocab at 0x125aa1438>,
#  'albus_dumbledore': <gensim.models.keyedvectors.Vocab at 0x125aa14a8>,
#  'seem_to': <gensim.models.keyedvectors.Vocab at 0x125aa1550>,
#  'realize_that': <gensim.models.keyedvectors.Vocab at 0x125aa13c8>,
#  'just_arrived': <gensim.models.keyedvectors.Vocab at 0x125aa12e8>,
#  'everything_from': <gensim.models.keyedvectors.Vocab at 0x125aa1588>,
#  'unwelcome': <gensim.models.keyedvectors.Vocab at 0x125aa15f8>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x125aa1518>,
#  'rummaging_in': <gensim.models.keyedvectors.Vocab at 0x125aa1630>,
#  'his_cloak': <gensim.models.keyedvectors.Vocab at 0x125aa1668>,
#  'looking_for': <gensim.models.keyedvectors.Vocab at 0x125aa16a0>,
#  'but_he': <gensim.models.keyedvectors.Vocab at 0x125aa1710>,
#  'did_seem': <gensim.models.keyedvectors.Vocab at 0x125aa1748>,
#  'to_realize': <gensim.models.keyedvectors.Vocab at 0x125aa16d8>,
#  'being_watched': <gensim.models.keyedvectors.Vocab at 0x125aa17b8>,
#  'looked_up': <gensim.models.keyedvectors.Vocab at 0x125aa1470>,
#  'which_was': <gensim.models.keyedvectors.Vocab at 0x125aa1828>,
#  'still_staring': <gensim.models.keyedvectors.Vocab at 0x125aa1860>,
#  'at_him': <gensim.models.keyedvectors.Vocab at 0x125aa18d0>,
#  'other_end': <gensim.models.keyedvectors.Vocab at 0x125aa1780>,
#  'for_some': <gensim.models.keyedvectors.Vocab at 0x125aa1908>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x125aa17f0>,
#  'the_sight': <gensim.models.keyedvectors.Vocab at 0x125aa1978>,
#  'muttered': <gensim.models.keyedvectors.Vocab at 0x125aa19b0>,
#  'i_should': <gensim.models.keyedvectors.Vocab at 0x125aa1a58>,
#  'have_known': <gensim.models.keyedvectors.Vocab at 0x125aa1898>,
#  'was_looking': <gensim.models.keyedvectors.Vocab at 0x125aa1ac8>,
#  'inside_pocket': <gensim.models.keyedvectors.Vocab at 0x125aa1a20>,
#  'it_seemed': <gensim.models.keyedvectors.Vocab at 0x125aa1940>,
#  'a_silver': <gensim.models.keyedvectors.Vocab at 0x125aa19e8>,
#  'he_flicked': <gensim.models.keyedvectors.Vocab at 0x125aa1b70>,
#  'it_open': <gensim.models.keyedvectors.Vocab at 0x125aa1a90>,
#  'held_it': <gensim.models.keyedvectors.Vocab at 0x125aa1be0>,
#  'air_and': <gensim.models.keyedvectors.Vocab at 0x125aa14e0>,
#  'the_nearest': <gensim.models.keyedvectors.Vocab at 0x125aa1c18>,
#  'went_out': <gensim.models.keyedvectors.Vocab at 0x125aa1c50>,
#  'with_a': <gensim.models.keyedvectors.Vocab at 0x125aa1c88>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x125aa1cc0>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x125aa1cf8>,
#  'he_clicked': <gensim.models.keyedvectors.Vocab at 0x125aa15c0>,
#  'the_next': <gensim.models.keyedvectors.Vocab at 0x125aa1d68>,
#  'into_darkness': <gensim.models.keyedvectors.Vocab at 0x125aa1ba8>,
#  'put_outer': <gensim.models.keyedvectors.Vocab at 0x125aa1dd8>,
#  'the_only': <gensim.models.keyedvectors.Vocab at 0x125aa1e10>,
#  'lights': <gensim.models.keyedvectors.Vocab at 0x125aa1e48>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x125aa1e80>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x125aa1eb8>,
#  'distance': <gensim.models.keyedvectors.Vocab at 0x125aa1ef0>,
#  'eyes': <gensim.models.keyedvectors.Vocab at 0x125aa1f28>,
#  'watching_him': <gensim.models.keyedvectors.Vocab at 0x125aa1b38>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x125aa1da0>,
#  'they_wouldn': <gensim.models.keyedvectors.Vocab at 0x125aa1d30>,
#  't_be': <gensim.models.keyedvectors.Vocab at 0x125aa1fd0>,
#  'able_to': <gensim.models.keyedvectors.Vocab at 0x125aa1f98>,
#  'see_anything': <gensim.models.keyedvectors.Vocab at 0x125aa1b00>,
#  'was_happening': <gensim.models.keyedvectors.Vocab at 0x125aa1f60>,
#  'down_on': <gensim.models.keyedvectors.Vocab at 0x125aa5080>,
#  'the_pavement': <gensim.models.keyedvectors.Vocab at 0x125aa50b8>,
#  'dumbledore': <gensim.models.keyedvectors.Vocab at 0x125aa50f0>,
#  'slipped': <gensim.models.keyedvectors.Vocab at 0x125aa5128>,
#  'back_inside': <gensim.models.keyedvectors.Vocab at 0x125aa5160>,
#  'off_down': <gensim.models.keyedvectors.Vocab at 0x125aa5198>,
#  'number_four': <gensim.models.keyedvectors.Vocab at 0x125aa51d0>,
#  'where_he': <gensim.models.keyedvectors.Vocab at 0x125aa5208>,
#  'sat_down': <gensim.models.keyedvectors.Vocab at 0x125aa5240>,
#  't_look': <gensim.models.keyedvectors.Vocab at 0x125aa52b0>,
#  'after_a': <gensim.models.keyedvectors.Vocab at 0x125aa52e8>,
#  'moment_he': <gensim.models.keyedvectors.Vocab at 0x125aa5358>,
#  'spoke_to': <gensim.models.keyedvectors.Vocab at 0x125aa5390>,
#  'fancy': <gensim.models.keyedvectors.Vocab at 0x125aa5400>,
#  'seeing_you': <gensim.models.keyedvectors.Vocab at 0x125aa5438>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x125aa5048>,
#  'professor_mcgonagall': <gensim.models.keyedvectors.Vocab at 0x125aa5470>,
#  'he_turned': <gensim.models.keyedvectors.Vocab at 0x125aa54a8>,
#  'smile': <gensim.models.keyedvectors.Vocab at 0x125aa54e0>,
#  'had_gone': <gensim.models.keyedvectors.Vocab at 0x125aa5518>,
#  'was_smiling': <gensim.models.keyedvectors.Vocab at 0x125aa5550>,
#  'a_rather': <gensim.models.keyedvectors.Vocab at 0x125aa55f8>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x125aa5278>,
#  'who_was': <gensim.models.keyedvectors.Vocab at 0x125aa5668>,
#  'wearing': <gensim.models.keyedvectors.Vocab at 0x125aa56a0>,
#  'square': <gensim.models.keyedvectors.Vocab at 0x125aa56d8>,
#  'glasses': <gensim.models.keyedvectors.Vocab at 0x125aa5710>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x125aa5748>,
#  'the_shape': <gensim.models.keyedvectors.Vocab at 0x125aa5780>,
#  'markings': <gensim.models.keyedvectors.Vocab at 0x125aa57b8>,
#  'around_its': <gensim.models.keyedvectors.Vocab at 0x125aa53c8>,
#  'black_hair': <gensim.models.keyedvectors.Vocab at 0x125aa5630>,
#  'was_drawn': <gensim.models.keyedvectors.Vocab at 0x125aa5898>,
#  'she_looked': <gensim.models.keyedvectors.Vocab at 0x125aa58d0>,
#  'distinctly': <gensim.models.keyedvectors.Vocab at 0x125aa5908>,
#  'ruffled': <gensim.models.keyedvectors.Vocab at 0x125aa5940>,
#  'how_did': <gensim.models.keyedvectors.Vocab at 0x125aa55c0>,
#  'she_asked': <gensim.models.keyedvectors.Vocab at 0x125aa5860>,
#  'professor': <gensim.models.keyedvectors.Vocab at 0x125aa5a20>,
#  'i_ve': <gensim.models.keyedvectors.Vocab at 0x125aa57f0>,
#  'never_seen': <gensim.models.keyedvectors.Vocab at 0x125aa5320>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x125aa5588>,
#  'stiff': <gensim.models.keyedvectors.Vocab at 0x125aa5a90>,
#  'd_been': <gensim.models.keyedvectors.Vocab at 0x125aa5b00>,
#  'sitting_on': <gensim.models.keyedvectors.Vocab at 0x125aa59e8>,
#  'a_brick': <gensim.models.keyedvectors.Vocab at 0x125aa5b38>,
#  'all_day': <gensim.models.keyedvectors.Vocab at 0x125aa59b0>,
#  'said_professor': <gensim.models.keyedvectors.Vocab at 0x125aa5b70>,
#  'mcgonagall': <gensim.models.keyedvectors.Vocab at 0x125aa5ba8>,
#  'when_you': <gensim.models.keyedvectors.Vocab at 0x125aa5978>,
#  'could_have': <gensim.models.keyedvectors.Vocab at 0x125aa5a58>,
#  'i_must': <gensim.models.keyedvectors.Vocab at 0x125aa5cc0>,
#  'a_dozen': <gensim.models.keyedvectors.Vocab at 0x125aa5828>,
#  'parties': <gensim.models.keyedvectors.Vocab at 0x125aa5c88>,
#  'on_my': <gensim.models.keyedvectors.Vocab at 0x125aa5ac8>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x125aa5d68>,
#  'sniffed': <gensim.models.keyedvectors.Vocab at 0x125aa5da0>,
#  'angrily': <gensim.models.keyedvectors.Vocab at 0x125aa5dd8>,
#  'everyone_s': <gensim.models.keyedvectors.Vocab at 0x125aa5c18>,
#  'all_right': <gensim.models.keyedvectors.Vocab at 0x125aa5d30>,
#  'impatiently': <gensim.models.keyedvectors.Vocab at 0x125aa5c50>,
#  'think_they': <gensim.models.keyedvectors.Vocab at 0x125aa5e80>,
#  'd_be': <gensim.models.keyedvectors.Vocab at 0x125aa5e48>,
#  'but_no': <gensim.models.keyedvectors.Vocab at 0x125aa5ef0>,
#  'the_muggles': <gensim.models.keyedvectors.Vocab at 0x125aa5f28>,
#  'have_noticed': <gensim.models.keyedvectors.Vocab at 0x125aa5f60>,
#  's_going': <gensim.models.keyedvectors.Vocab at 0x125aa5f98>,
#  'on_their': <gensim.models.keyedvectors.Vocab at 0x125aa5be0>,
#  'she_jerked': <gensim.models.keyedvectors.Vocab at 0x125aa5cf8>,
#  'her_head': <gensim.models.keyedvectors.Vocab at 0x125aa5fd0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x125aa5eb8>,
#  'of_owls': <gensim.models.keyedvectors.Vocab at 0x125aa5e10>,
#  'they_re': <gensim.models.keyedvectors.Vocab at 0x125a8e048>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x125a8e080>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x125a8e0b8>,
#  'bound_to': <gensim.models.keyedvectors.Vocab at 0x125a8e0f0>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x125a8e128>,
#  'i_ll': <gensim.models.keyedvectors.Vocab at 0x125a8e160>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x125a8e198>,
#  'dedalus_diggle': <gensim.models.keyedvectors.Vocab at 0x125a8e1d0>,
#  'never_had': <gensim.models.keyedvectors.Vocab at 0x125a8e208>,
#  'you_can': <gensim.models.keyedvectors.Vocab at 0x125a8e240>,
#  'said_dumbledore': <gensim.models.keyedvectors.Vocab at 0x125a8e278>,
#  'gently': <gensim.models.keyedvectors.Vocab at 0x125a8e320>,
#  'we_ve': <gensim.models.keyedvectors.Vocab at 0x125a8e2b0>,
#  'to_celebrate': <gensim.models.keyedvectors.Vocab at 0x125a8e358>,
#  'for_eleven': <gensim.models.keyedvectors.Vocab at 0x125a8e390>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x125a8e2e8>,
#  'i_know': <gensim.models.keyedvectors.Vocab at 0x125a8e400>,
#  'to_lose': <gensim.models.keyedvectors.Vocab at 0x125a8e438>,
#  'people_are': <gensim.models.keyedvectors.Vocab at 0x125a8e4a8>,
#  'careless': <gensim.models.keyedvectors.Vocab at 0x125a8e4e0>,
#  'not_even': <gensim.models.keyedvectors.Vocab at 0x125a8e470>,
#  'rumors': <gensim.models.keyedvectors.Vocab at 0x125a8e518>,
#  'she_threw': <gensim.models.keyedvectors.Vocab at 0x125a8e550>,
#  'a_sharp': <gensim.models.keyedvectors.Vocab at 0x125a8e588>,
#  'she_went': <gensim.models.keyedvectors.Vocab at 0x125a8e5c0>,
#  'a_fine': <gensim.models.keyedvectors.Vocab at 0x125a8e5f8>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x125a8e630>,
#  'it_would': <gensim.models.keyedvectors.Vocab at 0x125a8e668>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x125a8e3c8>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x125a8e6a0>,
#  'seems_to': <gensim.models.keyedvectors.Vocab at 0x125a8e710>,
#  'us_all': <gensim.models.keyedvectors.Vocab at 0x125a8e748>,
#  'we_have': <gensim.models.keyedvectors.Vocab at 0x125a8e780>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x125a8e7f0>,
#  'you_care': <gensim.models.keyedvectors.Vocab at 0x125a8e828>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x125a8e860>,
#  'a_kind': <gensim.models.keyedvectors.Vocab at 0x125a8e898>,
#  'of_muggle': <gensim.models.keyedvectors.Vocab at 0x125a8e8d0>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x125a8e6d8>,
#  'i_m': <gensim.models.keyedvectors.Vocab at 0x125a8e908>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x125a8e940>,
#  'fond_of': <gensim.models.keyedvectors.Vocab at 0x125a8e978>,
#  'she_didn': <gensim.models.keyedvectors.Vocab at 0x125a8e9b0>,
#  'the_moment': <gensim.models.keyedvectors.Vocab at 0x125a8e7b8>,
#  'i_say': <gensim.models.keyedvectors.Vocab at 0x125a8ea20>,
#  'surely': <gensim.models.keyedvectors.Vocab at 0x125a8ea58>,
#  'sensible': <gensim.models.keyedvectors.Vocab at 0x125a8ea90>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x125a8eac8>,
#  'i_have': <gensim.models.keyedvectors.Vocab at 0x125a8eb00>,
#  'been_trying': <gensim.models.keyedvectors.Vocab at 0x125a8eb38>,
#  'to_persuade': <gensim.models.keyedvectors.Vocab at 0x125a8eb70>,
#  'to_call': <gensim.models.keyedvectors.Vocab at 0x125a8eba8>,
#  'voldemort': <gensim.models.keyedvectors.Vocab at 0x125a8ec18>,
#  'dumbledore_who': <gensim.models.keyedvectors.Vocab at 0x125a8ec50>,
#  'seemed': <gensim.models.keyedvectors.Vocab at 0x125a8ec88>,
#  'to_notice': <gensim.models.keyedvectors.Vocab at 0x125a8ecc0>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x125a8ecf8>,
#  'if_we': <gensim.models.keyedvectors.Vocab at 0x125a8ed30>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x125a8ed68>,
#  'reason_to': <gensim.models.keyedvectors.Vocab at 0x125a8eda0>,
#  'sounding': <gensim.models.keyedvectors.Vocab at 0x125a8edd8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x125a8ee10>,
#  'admiring': <gensim.models.keyedvectors.Vocab at 0x125a8ee48>,
#  'you_re': <gensim.models.keyedvectors.Vocab at 0x125a8ee80>,
#  'everyone_knows': <gensim.models.keyedvectors.Vocab at 0x125a8eeb8>,
#  'oh_all': <gensim.models.keyedvectors.Vocab at 0x125a8eef0>,
#  'voldemort_was': <gensim.models.keyedvectors.Vocab at 0x125a8ef28>,
#  'frightened_of': <gensim.models.keyedvectors.Vocab at 0x125a8ef60>,
#  'me_said': <gensim.models.keyedvectors.Vocab at 0x125a8ef98>,
#  'dumbledore_calmly': <gensim.models.keyedvectors.Vocab at 0x125a8efd0>,
#  'voldemort_had': <gensim.models.keyedvectors.Vocab at 0x125a8e9e8>,
#  'will_never': <gensim.models.keyedvectors.Vocab at 0x125a8ebe0>,
#  'only_because': <gensim.models.keyedvectors.Vocab at 0x125c08048>,
#  'too_well': <gensim.models.keyedvectors.Vocab at 0x125c08080>,
#  'noble': <gensim.models.keyedvectors.Vocab at 0x125c080b8>,
#  'to_use': <gensim.models.keyedvectors.Vocab at 0x125c080f0>,
#  'lucky': <gensim.models.keyedvectors.Vocab at 0x125c08128>,
#  'i_haven': <gensim.models.keyedvectors.Vocab at 0x125c08160>,
#  'madam_pomfrey': <gensim.models.keyedvectors.Vocab at 0x125c08198>,
#  'told_me': <gensim.models.keyedvectors.Vocab at 0x125c081d0>,
#  'she_liked': <gensim.models.keyedvectors.Vocab at 0x125c08208>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x125c08240>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x125c08278>,
#  'earmuffs': <gensim.models.keyedvectors.Vocab at 0x125c082b0>,
#  'shot_a': <gensim.models.keyedvectors.Vocab at 0x125c082e8>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x125c08320>,
#  'rumors_that': <gensim.models.keyedvectors.Vocab at 0x125c08358>,
#  'flying_around': <gensim.models.keyedvectors.Vocab at 0x125c08390>,
#  'saying_about': <gensim.models.keyedvectors.Vocab at 0x125c083c8>,
#  'why_he': <gensim.models.keyedvectors.Vocab at 0x125c08400>,
#  'disappeared': <gensim.models.keyedvectors.Vocab at 0x125c08438>,
#  'about_what': <gensim.models.keyedvectors.Vocab at 0x125c08470>,
#  'had_reached': <gensim.models.keyedvectors.Vocab at 0x125c084a8>,
#  'the_point': <gensim.models.keyedvectors.Vocab at 0x125c084e0>,
#  'she_was': <gensim.models.keyedvectors.Vocab at 0x125c08518>,
#  'to_discuss': <gensim.models.keyedvectors.Vocab at 0x125c08550>,
#  'the_real': <gensim.models.keyedvectors.Vocab at 0x125c08588>,
#  'she_had': <gensim.models.keyedvectors.Vocab at 0x125c085c0>,
#  'been_waiting': <gensim.models.keyedvectors.Vocab at 0x125c085f8>,
#  'a_cold': <gensim.models.keyedvectors.Vocab at 0x125c08630>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x125c08668>,
#  ...}

# %%
# Out:
# /Users/isthatyoung/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('he', 0.7092324495315552),
#  ('miserably', 0.6743369102478027),
#  ('desperately', 0.6646770238876343),
#  ('resentfully', 0.6608796119689941),
#  ('overwhelmed', 0.6577586531639099),
#  ('savagely', 0.6529503464698792),
#  ('frank', 0.6519330739974976),
#  ('scrimgeour', 0.6514654159545898),
#  ('panicked', 0.6509665250778198),
#  ('tentatively', 0.6506140232086182)]

# %%
model.wv.similarity('harry','hermione')
# Out:
# 0.6830714

# %%
model.most_similar_cosmul('harry')
# Out:
# /Users/isthatyoung/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   """Entry point for launching an IPython kernel.
# [('he', 0.8960133790969849),
#  ('ron', 0.8694971203804016),
#  ('i_forgot', 0.863018274307251),
#  ('stan_shunpike', 0.8558216094970703),
#  ('madam_bones', 0.8505066633224487),
#  ('good_night', 0.8488210439682007),
#  ('play_quidditch', 0.8484007120132446),
#  ('looking_anxious', 0.8457697629928589),
#  ('very_seriously', 0.8452234268188477),
#  ('new_password', 0.8451986312866211)]

# %%
# Out:
# array([-0.10538466,  0.1134719 , -0.16092478,  0.05737837, -0.26285267,
#        -0.11558978,  0.10352044,  0.05921986, -0.02426692,  0.00220254,
#         0.1303996 ,  0.10257306,  0.39767608, -0.08240068,  0.00655096,
#         0.20718464, -0.10099807, -0.21434212,  0.23608279,  0.16969377,
#         0.02616698, -0.23795901, -0.04561288,  0.07550181,  0.09279141,
#         0.04468953, -0.0615638 , -0.06419189, -0.3671047 , -0.07695533,
#        -0.05916025, -0.47941932, -0.04922445, -0.07832174,  0.36288717,
#        -0.08847526, -0.3451319 , -0.1063392 , -0.2790955 , -0.12003071,
#         0.00715611,  0.20550203,  0.08418089,  0.06150657,  0.01911921,
#        -0.12072968,  0.16698514,  0.11085666, -0.12505902, -0.06534868,
#         0.167173  ,  0.05246569,  0.04527961,  0.07834763, -0.13004418,
#         0.27305564,  0.04464542, -0.10872785, -0.13519038,  0.10740414,
#        -0.15508223,  0.05635812, -0.10490892, -0.02448834,  0.04793334,
#        -0.01781727,  0.19691166,  0.07804927,  0.17562617, -0.00796   ,
#        -0.36765215,  0.15548155, -0.09697849,  0.10587721,  0.15931691,
#        -0.1891433 ,  0.0119443 , -0.03053842, -0.12946768,  0.03717181,
#        -0.30215737,  0.12041487, -0.0232508 , -0.2966201 ,  0.0899284 ,
#         0.3317672 ,  0.18839936, -0.09073018,  0.06941403,  0.42935643,
#         0.11221976, -0.10811245, -0.24715269,  0.17645097, -0.00840566,
#        -0.16312847, -0.00610255,  0.31718382, -0.07157692,  0.00487401],
#       dtype=float32)

# %%
'harry' in model.wv.vocab
# Out:
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-d0675daefd1c> in <module>
# ----> 1 print(list(model.wv.vocab['harry']))
#
# TypeError: 'Vocab' object is not iterable
